# %% [markdown]
# ##### Hipótesis
# Antes de seguir, recordamos las preguntas que nos planteamos al principio del pair programming de EDA para dirigir nuestro análisis.
# * ¿Es Australia el sitio más peligroso y letal para estar relajada en la playa?
# * ¿Hay diferencias entre los paises en los ataques a hombres y mujeres?
# * ¿Cuáles son las edades que más sufren ataques?
# * Independientemente de la edad, ¿sufren los hombres más ataques que las mujeres?
# * ¿En qué mes ocurren más ataques?
# * ¿Cuál es la relación entre la especie y el tipo de ataque (si es fatal o no)?
#
# * ¿Cómo han evolucionado los ataques a lo largo del tiempo?
#
# De todo esto, nos damos cuenta que solo tenemos que limpiar algunas de las columnas, en concreto age, species, country, fatal, year, sex. Reducimos esto a una tabla para saber qué tenemos ya limpito y qué no. Actualizamos esta tabla ya que en el ejercicio de pair de Limpieza I ya dejamos algunas columnas limpitas:
# variable
#
# ¿Está limpia?
#
# age
# ❌ esta en formato string cuando debería ser integer, y en algunos casos tenemos rangos de edad
#
# species
# ❌ es un jaleo! Debemos unificar los nombres y reducir a las especies más importantes
#
# country
# ❌ los paises están en mayúsculas, algunos se repiten con algunos cambios
#
# fatal
# ✔️ la limpiamos en el pair de Pandas V
#
# year
# ❌ es una columna de tipo float, deberíamos convertirla a integer
#
# sex
# ✔️ la limpiamos en el pair de Pandas V
#
# fecha
# ✔️ la limpiamos en el pair de Pandas V

# %%
import pandas as pd
import numpy as np
import sidetable
pd.options.display.max_columns=None

# %%
df = pd.read_csv('datos/attacks_limpieza_1.csv', index_col=0)

# %% [markdown]
# ##### Objetivos
# Usad la librería sidetable para:
# 1. Explorar los valores nulos.

# %%
df.stb.missing()
# Out:
#              missing  total    percent
# month            181   1672  10.825359
# time             160   1672   9.569378
# age              154   1672   9.210526
# species_         126   1672   7.535885
# fatal_y/n         99   1672   5.921053
# location          51   1672   3.050239
# area              46   1672   2.751196
# activity          31   1672   1.854067
# country           10   1672   0.598086
# name               9   1672   0.538278
# case_number        0   1672   0.000000
# year               0   1672   0.000000
# type               0   1672   0.000000
# href               0   1672   0.000000
# date               0   1672   0.000000
# sex_m_f            0   1672   0.000000

# %%
# Volvemos a mirar los tipos de datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1672 entries, 0 to 1671
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   case_number  1672 non-null   object
#  1   year         1672 non-null   int64
#  2   type         1672 non-null   object
#  3   country      1662 non-null   object
#  4   area         1626 non-null   object
#  5   location     1621 non-null   object
#  6   activity     1641 non-null   object
#  7   name         1663 non-null   object
#  8   age          1518 non-null   object
#  9   time         1512 non-null   object
#  10  species_     1546 non-null   object
#  11  href         1672 non-null   object
#  12  date         1672 non-null   object
#  13  month        1491 non-null   object
#  14  fatal_y/n    1573 non-null   object
#  15  sex_m_f      1672 non-null   object
# dtypes: int64(1), object(15)
# memory usage: 222.1+ KB

# %% [markdown]
# 2. Explorad la columna de country y reportad los resultados solo para aquellas categorías que incluyan el 70% de los datos.

# %%
df.stb.freq(['country'], thresh= 70)
# Out:
#      country  count    percent  cumulative_count  cumulative_percent
# 0        usa    741  44.584838               741           44.584838
# 1  australia    343  20.637786              1084           65.222623
# 2     others    578  34.777377              1662          100.000000

# %%
# La mayoria de reportes vienen de USA y Australia

# %% [markdown]
# 3. Explorad la columna country en relación al sexo, filtrando de nuevo por aquellas categorías que incluyan el 70% de los datos.

# %%
df.stb.freq(['country', 'sex_m_f'], thresh= 70)
# Out:
#         country sex_m_f  count    percent  cumulative_count  \
# 0           usa       M    610  36.702768               610
# 1     australia       M    310  18.652226               920
# 2  south africa       M    224  13.477738              1144
# 3        others  others    518  31.167268              1662
#
#    cumulative_percent
# 0           36.702768
# 1           55.354994
# 2           68.832732
# 3          100.000000

# %%
# Lo más típico son los ataques en USA a hombres (según estos datos)

# %% [markdown]
# 4. Haced los mismo para la columna activity en relación a la columna fatal. En este caso filtrad y mostrad los datos que incluyan el 60% de los datos.

# %%
df.stb.freq(['activity', 'fatal_y/n'], thresh= 60)
# Out:
#          activity fatal_y/n  count    percent  cumulative_count  \
# 0         Surfing         N    380  24.531956               380
# 1        Swimming         N    139   8.973531               519
# 2    Spearfishing         N     85   5.487411               604
# 3        Swimming         Y     79   5.100065               683
# 4         Fishing         N     50   3.227889               733
# 5          Wading         N     43   2.775985               776
# 6        Standing         N     30   1.936733               806
# 7      Snorkeling         N     29   1.872176               835
# 8         Surfing         Y     26   1.678502               861
# 9   Body boarding         N     24   1.549387               885
# 10         Diving         N     19   1.226598               904
# 11   Scuba diving         N     17   1.097482               921
# 12         others    others    628  40.542285              1549
#
#     cumulative_percent
# 0            24.531956
# 1            33.505487
# 2            38.992899
# 3            44.092963
# 4            47.320852
# 5            50.096837
# 6            52.033570
# 7            53.905746
# 8            55.584248
# 9            57.133635
# 10           58.360232
# 11           59.457715
# 12          100.000000

# %%
# Los ataques más comunes suceden durante la actividad de surf y no son letales.

# %% [markdown]
# 5. Por último, realizad este análisis para la columna fecha (la que creamos en el último ejercicio de pair programming de Pandas) en relación a la columna fatal. Mostrad solo los resultados para las categorías que incluyan el 60% de los datos.
#
# 📌 Nota Igual que siempre, no nos vale solo con picar el código, queremos que nos incluyais las conclusiones que extraeis.

# %%
df.head(2)
# Out:
#     case_number  year        type country        area  \
# 0    2018.06.25  2018     Boating     usa  California
# 1  2018.06.03.a  2018  Unprovoked  brazil  Pernambuco
#
#                       location  activity                    name age  \
# 0  Oceanside, San Diego County  Paddling             Julie Wolfe  57
# 1        Piedade Beach, Recife  Swimming  Jose Ernesto da Silva   18
#
#              time     species_  \
# 0           18h00  White shark
# 1  Late afternoon  Tiger shark
#
#                                                 href         date month  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  25-Jun-2018   Jun
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  03-Jun-2018   Jun
#
#   fatal_y/n sex_m_f
# 0         N       F
# 1         Y       M

# %%
df.stb.freq(['month', 'fatal_y/n'], thresh= 60)
# Out:
#     month fatal_y/n  count    percent  cumulative_count  cumulative_percent
# 0     Oct         N    128   9.071580               128            9.071580
# 1     Aug         N    122   8.646350               250           17.717931
# 2     Sep         N    121   8.575478               371           26.293409
# 3     Jul         N    112   7.937633               483           34.231042
# 4     Jun         N    108   7.654146               591           41.885188
# 5     Apr         N     93   6.591070               684           48.476258
# 6     May         N     91   6.449327               775           54.925585
# 7  others    others    636  45.074415              1411          100.000000

# %%
# Segun estos datos el mes mas típico para los ataques de tiburon es octubre y no son letales

# %% [markdown]
# ##### Conclusiones
# Si bien es cierto que la lección de hoy ha sido muy teórica, en esta parte los ejercicios no serán tanto de programar sino de pensar 🤔. ¿Qué tendréis que hacer?
# * En relación a los valores nulos:
#     * Identificar las columnas que tienen nulos (lo hicimos en el ejercicio de pair programming EDA I y en el de hoy con el sidetable).
#
#     * Debatid entre vosotras qué haríais con los valores nulos, ¿los quitaríais o los reemplazaríais con un valor que nosotras decidiremos?. Cread una celda de markdown en vuestro jupyter y escribid vuestras conclusiones.
#
# * En relación a los outliers, ya hemos ido conociendo un poco nuestro dataframe y de momento solo tenemos una columna de tipo numérico, por lo tanto, poco podemos hacer. Un poco más adelante, cuando hayamos hecho una serie de cambios sobre nuestras columnas podremos hacer una evaluación más profunda de estos.

# %% [markdown]
# ##### `nulos`
# * La columna que tiene más nulos es la columna `siglo`. ESto peude deberse a un fallo en la limpieza durante los ejercicios anteriores.
# * Esto lo solventaremos en caso de necesitar esa columna para nuestros análisis.
# * La cantidad de nulos en el resto de las columnas es manejable.
# * Iremos considerando si eliminarlos en relación a los análisis futuros que hagamos

# %% [markdown]
# ##### `otras conclusiones`
# * La mayoria de reportes vienen de **USA** y **AUSTRALIA**
# * Lo más típico son los ataques en **USA a hombres** (según estos datos)
# * Los ataques más comunes suceden durante la actividad de **surf** y **no son letales**.
# * Segun estos datos el mes mas típico para los ataques de tiburon es **octubre** y **no son letales**.

# %% [markdown]
# En la lección de hoy aprendimos como transformar nuestros datos para que estén preparados para almacearlos en una BBDD. En este momento tenemos dos fuentes de datos:
#
# 1. El csv con los ataques de tiburones que hemos estado limpiando hasta ahora, el que os hemos adjuntado (attacks_limpieza_completa). Sentiros libres de usar vuestros propios csv en caso de que queráis.
#
# 2. El csv con los datos climáticos de los principales paises que tienen ataques de tiburones, el que creamos en el pair programming de ayer.

# %% [markdown]
# >El objetivo de la sesión de hoy será juntar en un único csv la información de ambas fuentes. Para ello:
# >
# >* Cargaremos los dos ficheros de datos
# >* Del dataframe de los ataques nos quedaremos solo con las filas de los países que seleccionamos en la lección de ayer:
# >    * USA
# >    * Australia
# >    * New Zealand
# >    * South Africa
# >    * Papua New Guinea
# >
# >* Del dataframe de los datos climáticos seleccionaremos todas las columnas.
# >* Cuando ya tengamos todos los datos deseados juntaremos los dos csv.
# >    * Para hacer esta unión tendremos que hacer un groupby en la tabla de clima para sacar una media de las medidas climáticas por país.
# >* Antes de hacer el groupby si nos fijamos tenemos dos columnas rh_profile y wind_profile cuya información es una lista de diccionarios. Os dejamos por aquí una posible solución que nos permite separar esa información en distintas columnas.
#
# ```python
# # os recomendamos resetear el index del dataframe de los datos climáticos para que no se repitan los nombres de las columnas.
# ​
# ​
# # El primer problema al que nos podemos enfrentar es que si vemos los tipos de las columnas vemos que estas columnas son objetos, es decir, strings, lo que hará que trabajar con ellas sea un poco complicado:
# clima.dtypes
# ​
# timepoint             int64
# cloudcover            int64
# highcloud             int64
# midcloud              int64
# lowcloud              int64
# rh_profile           object
# wind_profile         object
# ​
# # en Python tenemos la librería `ast` que nos permite castear un string que dentro tiene diccionarios, o listas o tuplas a su tipo correspondiente. En nuestro caso, lo que conseguiremos es no tener strings sino listas en la columna. Esto lo haremos de la siguiente forma:
# ​
# import ast
# ​
# clima['wind_profile']= clima['wind_profile'].apply(ast.literal_eval)
# ​
# # una vez que tengamos la columna cambiada, una fantasía de Pandas es que si hago un apply sobre una columna cuyos valores son diccionarios o listas nos va a genererar una columna con los valores de los diccionarios o listas. Donde cada columna será key del diccionario o cada elemento de la lista.
# ​
# ​
# x = clima['wind_profile'].apply(pd.Series)
# ​
# ​
# # nos creamos un dataframe nuevo con el resultado de la información de una de las columnas separadas por columnas. Esto nos va a devolver un dataframe donde cada fila será una celda del dataframe anterior.
# x = df['rh_profile'].apply(pd.Series)
# ​
# # ¿Qué es lo que ocurre cuando hacemos esto?
# # Nos ha creado tantas columnas como valores tuvieramos en la lista. Donde columna es, en este caso, un diccionario (porque nuestra lista esta compuesta por distintos diccionarios)
# ​
# # Ok, hemos conseguido desempaquetar la información de la lista en distintas columnas. Ahora tenemos que despempaquetar la información de los diccionarios en distintas columnas. En este caso, lo que querremos es que las key de los diccionarios sean los nombres de las columnas y los values los valores de las celdas del dataframe. Volveremos a seguir entonces la misma lógica que antes con el apply, pero en este caso necesitamos hacerlo para todo el dataframe (que es x):
# ​
# # Por eso empezamos con un for para iterar por cada una de las columnas.
# for i in range(len(x.columns)):
# ​
#     # aplicamos el apply,extraemos el valore de la key "layer" y lo almacenamos en una variable que convertimos a string
#     nombre = "rh_" + str(x[i].apply(pd.Series)["layer"][0])
# ​
#     # hacemos lo mismo con una variable que se llame valores para "guardar" los valores de la celda
#     valores = list(x[i].apply(pd.Series)["rh"] )
# ​
#     # usamos el método insert de los dataframes para ir añadiendo esta información a el dataframe con la información del clima.
#     df.insert(i, nombre, valores)
# ​
# # una vez que hayamos hecho esto para las dos columnas ya podremos hacer el gropuby para después unir toda la información.
# ```
#
# > * Guardar los resultados obtenidos en un csv que usaremos en próximos ejercicios de pair programming.

# %% [markdown]
# ##### Importamos librerías

# %%
from IPython.core.interactiveshell import InteractiveShell 
InteractiveShell.ast_node_interactivity = "all"

import requests
import pandas as pd
import numpy as np
import ast

pd.options.display.max_columns=None
#pd.options.display.max_rows=5
pd.options.display.max_rows=None

# %% [markdown]
# ##### Cargamos dataframes

# %%
df_attacks = pd.read_csv('datos/input/attacks_limpieza_completa.csv', index_col =0)

# %%
df_clima = pd.read_pickle('datos/input/datos_clima_paises.pkl')

# %%
df_attacks.head(1)
# Out:
#    year     type country   age     species_ fecha_limpia fatal sex   latitud  \
# 0  2018  Boating     usa  57.0  White shark          Jun     N   F  39.78373
#
#      longitud country2  fatal_N  fatal_Unknown  fatal_Y  fatal_N.1  \
# 0 -100.445882       HN        1              0        0          1
#
#    fatal_Unknown.1  fatal_Y.1  species_.1  fecha_limpia.1  type.1  age_NORM
# 0                0          0           4               7       1  9.116327

# %%
df_clima.head(1)
# Out:
#    timepoint  cloudcover  highcloud  midcloud  lowcloud  \
# 0          3           1      -9999     -9999     -9999
#
#                                           rh_profile  \
# 0  [{'layer': '950mb', 'rh': 4}, {'layer': '900mb...
#
#                                         wind_profile  temp2m  lifted_index  \
# 0  [{'layer': '950mb', 'direction': 155, 'speed':...      27             2
#
#    rh2m  msl_pressure prec_type  prec_amount  snow_depth wind10m.direction  \
# 0     2          1011      none            0           0               190
#
#    wind10m.speed pais   latitud    longitud
# 0              2  usa  39.78373 -100.445882

# %% [markdown]
# ##### Seleccionamos los paises que nos interesan del df attacks

# %%
# Sacamos la lista de paises para los que tenemos los datos climáticos
lista_paises = list(df_clima['pais'].unique())
lista_paises
# Out:
# ['usa', 'australia', 'south africa', 'new zealand', 'papua new guinea']

# %%
# Filtramos el df attacks por los paises que queremos
df_paises = df_attacks[df_attacks['country'].isin(lista_paises)]
df_paises.head(2)
# Out:
#    year        type country   age     species_ fecha_limpia fatal sex  \
# 0  2018     Boating     usa  57.0  White shark          Jun     N   F
# 1  2018  Unprovoked     usa  11.0  Unespecific          Jun     N   F
#
#     latitud    longitud country2  fatal_N  fatal_Unknown  fatal_Y  fatal_N.1  \
# 0  39.78373 -100.445882       HN        1              0        0          1
# 1  39.78373 -100.445882       HN        1              0        0          1
#
#    fatal_Unknown.1  fatal_Y.1  species_.1  fecha_limpia.1  type.1  age_NORM
# 0                0          0           4               7       1  9.116327
# 1                0          0           3               7       7  3.804860

# %%
# Comprobamos
df_paises['country'].unique()
# Out:
# array(['usa', 'australia', 'south africa', 'new zealand',
#        'papua new guinea'], dtype=object)

# %% [markdown]
# ##### Desempaquetamos las columnas `rh_profile` y `wind_profile` del df clima

# %%
df_clima.head(2)
# Out:
#    timepoint  cloudcover  highcloud  midcloud  lowcloud  \
# 0          3           1      -9999     -9999     -9999
# 1          6           1      -9999     -9999     -9999
#
#                                           rh_profile  \
# 0  [{'layer': '950mb', 'rh': 4}, {'layer': '900mb...
# 1  [{'layer': '950mb', 'rh': 3}, {'layer': '900mb...
#
#                                         wind_profile  temp2m  lifted_index  \
# 0  [{'layer': '950mb', 'direction': 155, 'speed':...      27             2
# 1  [{'layer': '950mb', 'direction': 155, 'speed':...      26             2
#
#    rh2m  msl_pressure prec_type  prec_amount  snow_depth wind10m.direction  \
# 0     2          1011      none            0           0               190
# 1     2          1010      none            0           0               155
#
#    wind10m.speed pais   latitud    longitud
# 0              2  usa  39.78373 -100.445882
# 1              2  usa  39.78373 -100.445882

# %%
# Creemos que por haber guardado en pkl no nos ha hecho falta hacer ningún casteo (de hecho nos daba error), así que nos ahorramos un paso
df_clima['rh_profile']
# Out:
# 0      [{'layer': '950mb', 'rh': 4}, {'layer': '900mb...
# 1      [{'layer': '950mb', 'rh': 3}, {'layer': '900mb...
# 2      [{'layer': '950mb', 'rh': 4}, {'layer': '900mb...
# 3      [{'layer': '950mb', 'rh': 5}, {'layer': '900mb...
# 4      [{'layer': '950mb', 'rh': 6}, {'layer': '900mb...
# 5      [{'layer': '950mb', 'rh': 5}, {'layer': '900mb...
# 6      [{'layer': '950mb', 'rh': 4}, {'layer': '900mb...
# 7      [{'layer': '950mb', 'rh': 4}, {'layer': '900mb...
# 8      [{'layer': '950mb', 'rh': 5}, {'layer': '900mb...
# 9      [{'layer': '950mb', 'rh': 4}, {'layer': '900mb...
# 10     [{'layer': '950mb', 'rh': 7}, {'layer': '900mb...
# 11     [{'layer': '950mb', 'rh': 8}, {'layer': '900mb...
# 12     [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 13     [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 14     [{'layer': '950mb', 'rh': 9}, {'layer': '900mb...
# 15     [{'layer': '950mb', 'rh': 6}, {'layer': '900mb...
# 16     [{'layer': '950mb', 'rh': 5}, {'layer': '900mb...
# 17     [{'layer': '950mb', 'rh': 9}, {'layer': '900mb...
# 18     [{'layer': '950mb', 'rh': 6}, {'layer': '900mb...
# 19     [{'layer': '950mb', 'rh': 7}, {'layer': '900mb...
# 20     [{'layer': '950mb', 'rh': 8}, {'layer': '900mb...
# 21     [{'layer': '950mb', 'rh': 8}, {'layer': '900mb...
# 22     [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 23     [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 24     [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 25     [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 26     [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 27     [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 28     [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 29     [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 30     [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 31     [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 32     [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 33     [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 34     [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 35     [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 36     [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 37     [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 38     [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 39     [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 40     [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 41     [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 42     [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 43     [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 44     [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 45     [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 46     [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 47     [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 48     [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 49     [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 50     [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 51     [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 52     [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 53     [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 54     [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 55     [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 56     [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 57     [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 58     [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 59     [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 60     [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 61     [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 62     [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 63     [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 64     [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 65     [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 66     [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 67     [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 68     [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 69     [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 70     [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 71     [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 72     [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 73     [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 74     [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 75     [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 76     [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 77     [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 78     [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 79     [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 80     [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 81     [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 82     [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 83     [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 84     [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 85     [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 86     [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 87     [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 88     [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 89     [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 90     [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 91     [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 92     [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 93     [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 94     [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 95     [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 96     [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 97     [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 98     [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 99     [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 100    [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 101    [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 102    [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 103    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 104    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 105    [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 106    [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 107    [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 108    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 109    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 110    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 111    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 112    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 113    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 114    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 115    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 116    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 117    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 118    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 119    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 120    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 121    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 122    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 123    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 124    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 125    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 126    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 127    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 128    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 129    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 130    [{'layer': '950mb', 'rh': 16}, {'layer': '900m...
# 131    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 132    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 133    [{'layer': '950mb', 'rh': 16}, {'layer': '900m...
# 134    [{'layer': '950mb', 'rh': 16}, {'layer': '900m...
# 135    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 136    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 137    [{'layer': '950mb', 'rh': 9}, {'layer': '900mb...
# 138    [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 139    [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 140    [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 141    [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 142    [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 143    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 144    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 145    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 146    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 147    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 148    [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 149    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 150    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 151    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 152    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 153    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 154    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 155    [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 156    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 157    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 158    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 159    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 160    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 161    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 162    [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 163    [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 164    [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 165    [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 166    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 167    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 168    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 169    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 170    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 171    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 172    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 173    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 174    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 175    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 176    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 177    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 178    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 179    [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 180    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 181    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 182    [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 183    [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 184    [{'layer': '950mb', 'rh': 9}, {'layer': '900mb...
# 185    [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 186    [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 187    [{'layer': '950mb', 'rh': 9}, {'layer': '900mb...
# 188    [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 189    [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 190    [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 191    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 192    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 193    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 194    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 195    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 196    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 197    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 198    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 199    [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 200    [{'layer': '950mb', 'rh': 8}, {'layer': '900mb...
# 201    [{'layer': '950mb', 'rh': 7}, {'layer': '900mb...
# 202    [{'layer': '950mb', 'rh': 8}, {'layer': '900mb...
# 203    [{'layer': '950mb', 'rh': 7}, {'layer': '900mb...
# 204    [{'layer': '950mb', 'rh': 8}, {'layer': '900mb...
# 205    [{'layer': '950mb', 'rh': 8}, {'layer': '900mb...
# 206    [{'layer': '950mb', 'rh': 9}, {'layer': '900mb...
# 207    [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 208    [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 209    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 210    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 211    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 212    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 213    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 214    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 215    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 216    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 217    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 218    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 219    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 220    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 221    [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 222    [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 223    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 224    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 225    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 226    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 227    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 228    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 229    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 230    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 231    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 232    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 233    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 234    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 235    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 236    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 237    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 238    [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 239    [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 240    [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 241    [{'layer': '950mb', 'rh': 9}, {'layer': '900mb...
# 242    [{'layer': '950mb', 'rh': 9}, {'layer': '900mb...
# 243    [{'layer': '950mb', 'rh': 8}, {'layer': '900mb...
# 244    [{'layer': '950mb', 'rh': 9}, {'layer': '900mb...
# 245    [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 246    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 247    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 248    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 249    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 250    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 251    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 252    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 253    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 254    [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 255    [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 256    [{'layer': '950mb', 'rh': 9}, {'layer': '900mb...
# 257    [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 258    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 259    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 260    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 261    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 262    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 263    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 264    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 265    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 266    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 267    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 268    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 269    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 270    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 271    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 272    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 273    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 274    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 275    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 276    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 277    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 278    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 279    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 280    [{'layer': '950mb', 'rh': 11}, {'layer': '900m...
# 281    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 282    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 283    [{'layer': '950mb', 'rh': 10}, {'layer': '900m...
# 284    [{'layer': '950mb', 'rh': 9}, {'layer': '900mb...
# 285    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 286    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 287    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 288    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 289    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 290    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 291    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 292    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 293    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 294    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 295    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 296    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 297    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 298    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 299    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 300    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 301    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 302    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 303    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 304    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 305    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 306    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 307    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 308    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 309    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 310    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 311    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 312    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 313    [{'layer': '950mb', 'rh': 15}, {'layer': '900m...
# 314    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 315    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 316    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 317    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 318    [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 319    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# Name: rh_profile, dtype: object

# %%
df_clima['wind_profile']
# Out:
# 0      [{'layer': '950mb', 'direction': 155, 'speed':...
# 1      [{'layer': '950mb', 'direction': 155, 'speed':...
# 2      [{'layer': '950mb', 'direction': 120, 'speed':...
# 3      [{'layer': '950mb', 'direction': 110, 'speed':...
# 4      [{'layer': '950mb', 'direction': 265, 'speed':...
# 5      [{'layer': '950mb', 'direction': 320, 'speed':...
# 6      [{'layer': '950mb', 'direction': 335, 'speed':...
# 7      [{'layer': '950mb', 'direction': 355, 'speed':...
# 8      [{'layer': '950mb', 'direction': 10, 'speed': ...
# 9      [{'layer': '950mb', 'direction': 110, 'speed':...
# 10     [{'layer': '950mb', 'direction': 170, 'speed':...
# 11     [{'layer': '950mb', 'direction': 205, 'speed':...
# 12     [{'layer': '950mb', 'direction': 200, 'speed':...
# 13     [{'layer': '950mb', 'direction': 230, 'speed':...
# 14     [{'layer': '950mb', 'direction': 240, 'speed':...
# 15     [{'layer': '950mb', 'direction': 300, 'speed':...
# 16     [{'layer': '950mb', 'direction': 250, 'speed':...
# 17     [{'layer': '950mb', 'direction': 165, 'speed':...
# 18     [{'layer': '950mb', 'direction': 105, 'speed':...
# 19     [{'layer': '950mb', 'direction': 140, 'speed':...
# 20     [{'layer': '950mb', 'direction': 155, 'speed':...
# 21     [{'layer': '950mb', 'direction': 105, 'speed':...
# 22     [{'layer': '950mb', 'direction': 105, 'speed':...
# 23     [{'layer': '950mb', 'direction': 160, 'speed':...
# 24     [{'layer': '950mb', 'direction': 165, 'speed':...
# 25     [{'layer': '950mb', 'direction': 185, 'speed':...
# 26     [{'layer': '950mb', 'direction': 200, 'speed':...
# 27     [{'layer': '950mb', 'direction': 185, 'speed':...
# 28     [{'layer': '950mb', 'direction': 200, 'speed':...
# 29     [{'layer': '950mb', 'direction': 190, 'speed':...
# 30     [{'layer': '950mb', 'direction': 205, 'speed':...
# 31     [{'layer': '950mb', 'direction': 295, 'speed':...
# 32     [{'layer': '950mb', 'direction': 110, 'speed':...
# 33     [{'layer': '950mb', 'direction': 130, 'speed':...
# 34     [{'layer': '950mb', 'direction': 155, 'speed':...
# 35     [{'layer': '950mb', 'direction': 170, 'speed':...
# 36     [{'layer': '950mb', 'direction': 175, 'speed':...
# 37     [{'layer': '950mb', 'direction': 190, 'speed':...
# 38     [{'layer': '950mb', 'direction': 160, 'speed':...
# 39     [{'layer': '950mb', 'direction': 100, 'speed':...
# 40     [{'layer': '950mb', 'direction': 155, 'speed':...
# 41     [{'layer': '950mb', 'direction': 165, 'speed':...
# 42     [{'layer': '950mb', 'direction': 155, 'speed':...
# 43     [{'layer': '950mb', 'direction': 180, 'speed':...
# 44     [{'layer': '950mb', 'direction': 195, 'speed':...
# 45     [{'layer': '950mb', 'direction': 200, 'speed':...
# 46     [{'layer': '950mb', 'direction': 190, 'speed':...
# 47     [{'layer': '950mb', 'direction': 210, 'speed':...
# 48     [{'layer': '950mb', 'direction': 190, 'speed':...
# 49     [{'layer': '950mb', 'direction': 175, 'speed':...
# 50     [{'layer': '950mb', 'direction': 165, 'speed':...
# 51     [{'layer': '950mb', 'direction': 155, 'speed':...
# 52     [{'layer': '950mb', 'direction': 205, 'speed':...
# 53     [{'layer': '950mb', 'direction': 190, 'speed':...
# 54     [{'layer': '950mb', 'direction': 10, 'speed': ...
# 55     [{'layer': '950mb', 'direction': 65, 'speed': ...
# 56     [{'layer': '950mb', 'direction': 95, 'speed': ...
# 57     [{'layer': '950mb', 'direction': 120, 'speed':...
# 58     [{'layer': '950mb', 'direction': 115, 'speed':...
# 59     [{'layer': '950mb', 'direction': 110, 'speed':...
# 60     [{'layer': '950mb', 'direction': 125, 'speed':...
# 61     [{'layer': '950mb', 'direction': 130, 'speed':...
# 62     [{'layer': '950mb', 'direction': 135, 'speed':...
# 63     [{'layer': '950mb', 'direction': 270, 'speed':...
# 64     [{'layer': '950mb', 'direction': 165, 'speed':...
# 65     [{'layer': '950mb', 'direction': 170, 'speed':...
# 66     [{'layer': '950mb', 'direction': 165, 'speed':...
# 67     [{'layer': '950mb', 'direction': 155, 'speed':...
# 68     [{'layer': '950mb', 'direction': 150, 'speed':...
# 69     [{'layer': '950mb', 'direction': 155, 'speed':...
# 70     [{'layer': '950mb', 'direction': 145, 'speed':...
# 71     [{'layer': '950mb', 'direction': 150, 'speed':...
# 72     [{'layer': '950mb', 'direction': 145, 'speed':...
# 73     [{'layer': '950mb', 'direction': 145, 'speed':...
# 74     [{'layer': '950mb', 'direction': 140, 'speed':...
# 75     [{'layer': '950mb', 'direction': 140, 'speed':...
# 76     [{'layer': '950mb', 'direction': 135, 'speed':...
# 77     [{'layer': '950mb', 'direction': 120, 'speed':...
# 78     [{'layer': '950mb', 'direction': 110, 'speed':...
# 79     [{'layer': '950mb', 'direction': 95, 'speed': ...
# 80     [{'layer': '950mb', 'direction': 90, 'speed': ...
# 81     [{'layer': '950mb', 'direction': 100, 'speed':...
# 82     [{'layer': '950mb', 'direction': 105, 'speed':...
# 83     [{'layer': '950mb', 'direction': 105, 'speed':...
# 84     [{'layer': '950mb', 'direction': 105, 'speed':...
# 85     [{'layer': '950mb', 'direction': 100, 'speed':...
# 86     [{'layer': '950mb', 'direction': 105, 'speed':...
# 87     [{'layer': '950mb', 'direction': 95, 'speed': ...
# 88     [{'layer': '950mb', 'direction': 85, 'speed': ...
# 89     [{'layer': '950mb', 'direction': 85, 'speed': ...
# 90     [{'layer': '950mb', 'direction': 85, 'speed': ...
# 91     [{'layer': '950mb', 'direction': 85, 'speed': ...
# 92     [{'layer': '950mb', 'direction': 70, 'speed': ...
# 93     [{'layer': '950mb', 'direction': 65, 'speed': ...
# 94     [{'layer': '950mb', 'direction': 60, 'speed': ...
# 95     [{'layer': '950mb', 'direction': 50, 'speed': ...
# 96     [{'layer': '950mb', 'direction': 40, 'speed': ...
# 97     [{'layer': '950mb', 'direction': 40, 'speed': ...
# 98     [{'layer': '950mb', 'direction': 40, 'speed': ...
# 99     [{'layer': '950mb', 'direction': 55, 'speed': ...
# 100    [{'layer': '950mb', 'direction': 65, 'speed': ...
# 101    [{'layer': '950mb', 'direction': 65, 'speed': ...
# 102    [{'layer': '950mb', 'direction': 65, 'speed': ...
# 103    [{'layer': '950mb', 'direction': 50, 'speed': ...
# 104    [{'layer': '950mb', 'direction': 55, 'speed': ...
# 105    [{'layer': '950mb', 'direction': 60, 'speed': ...
# 106    [{'layer': '950mb', 'direction': 75, 'speed': ...
# 107    [{'layer': '950mb', 'direction': 85, 'speed': ...
# 108    [{'layer': '950mb', 'direction': 80, 'speed': ...
# 109    [{'layer': '950mb', 'direction': 100, 'speed':...
# 110    [{'layer': '950mb', 'direction': 110, 'speed':...
# 111    [{'layer': '950mb', 'direction': 105, 'speed':...
# 112    [{'layer': '950mb', 'direction': 90, 'speed': ...
# 113    [{'layer': '950mb', 'direction': 90, 'speed': ...
# 114    [{'layer': '950mb', 'direction': 90, 'speed': ...
# 115    [{'layer': '950mb', 'direction': 90, 'speed': ...
# 116    [{'layer': '950mb', 'direction': 85, 'speed': ...
# 117    [{'layer': '950mb', 'direction': 90, 'speed': ...
# 118    [{'layer': '950mb', 'direction': 95, 'speed': ...
# 119    [{'layer': '950mb', 'direction': 95, 'speed': ...
# 120    [{'layer': '950mb', 'direction': 95, 'speed': ...
# 121    [{'layer': '950mb', 'direction': 95, 'speed': ...
# 122    [{'layer': '950mb', 'direction': 95, 'speed': ...
# 123    [{'layer': '950mb', 'direction': 85, 'speed': ...
# 124    [{'layer': '950mb', 'direction': 75, 'speed': ...
# 125    [{'layer': '950mb', 'direction': 80, 'speed': ...
# 126    [{'layer': '950mb', 'direction': 75, 'speed': ...
# 127    [{'layer': '950mb', 'direction': 75, 'speed': ...
# 128    [{'layer': '950mb', 'direction': 35, 'speed': ...
# 129    [{'layer': '950mb', 'direction': 20, 'speed': ...
# 130    [{'layer': '950mb', 'direction': 0, 'speed': 5...
# 131    [{'layer': '950mb', 'direction': 320, 'speed':...
# 132    [{'layer': '950mb', 'direction': 310, 'speed':...
# 133    [{'layer': '950mb', 'direction': 305, 'speed':...
# 134    [{'layer': '950mb', 'direction': 295, 'speed':...
# 135    [{'layer': '950mb', 'direction': 260, 'speed':...
# 136    [{'layer': '950mb', 'direction': 260, 'speed':...
# 137    [{'layer': '950mb', 'direction': 270, 'speed':...
# 138    [{'layer': '950mb', 'direction': 270, 'speed':...
# 139    [{'layer': '950mb', 'direction': 260, 'speed':...
# 140    [{'layer': '950mb', 'direction': 285, 'speed':...
# 141    [{'layer': '950mb', 'direction': 290, 'speed':...
# 142    [{'layer': '950mb', 'direction': 305, 'speed':...
# 143    [{'layer': '950mb', 'direction': 305, 'speed':...
# 144    [{'layer': '950mb', 'direction': 300, 'speed':...
# 145    [{'layer': '950mb', 'direction': 320, 'speed':...
# 146    [{'layer': '950mb', 'direction': 325, 'speed':...
# 147    [{'layer': '950mb', 'direction': 300, 'speed':...
# 148    [{'layer': '950mb', 'direction': 325, 'speed':...
# 149    [{'layer': '950mb', 'direction': 350, 'speed':...
# 150    [{'layer': '950mb', 'direction': 25, 'speed': ...
# 151    [{'layer': '950mb', 'direction': 355, 'speed':...
# 152    [{'layer': '950mb', 'direction': 10, 'speed': ...
# 153    [{'layer': '950mb', 'direction': 350, 'speed':...
# 154    [{'layer': '950mb', 'direction': 340, 'speed':...
# 155    [{'layer': '950mb', 'direction': 345, 'speed':...
# 156    [{'layer': '950mb', 'direction': 35, 'speed': ...
# 157    [{'layer': '950mb', 'direction': 30, 'speed': ...
# 158    [{'layer': '950mb', 'direction': 320, 'speed':...
# 159    [{'layer': '950mb', 'direction': 325, 'speed':...
# 160    [{'layer': '950mb', 'direction': 285, 'speed':...
# 161    [{'layer': '950mb', 'direction': 235, 'speed':...
# 162    [{'layer': '950mb', 'direction': 210, 'speed':...
# 163    [{'layer': '950mb', 'direction': 175, 'speed':...
# 164    [{'layer': '950mb', 'direction': 200, 'speed':...
# 165    [{'layer': '950mb', 'direction': 200, 'speed':...
# 166    [{'layer': '950mb', 'direction': 205, 'speed':...
# 167    [{'layer': '950mb', 'direction': 165, 'speed':...
# 168    [{'layer': '950mb', 'direction': 120, 'speed':...
# 169    [{'layer': '950mb', 'direction': 115, 'speed':...
# 170    [{'layer': '950mb', 'direction': 115, 'speed':...
# 171    [{'layer': '950mb', 'direction': 105, 'speed':...
# 172    [{'layer': '950mb', 'direction': 85, 'speed': ...
# 173    [{'layer': '950mb', 'direction': 90, 'speed': ...
# 174    [{'layer': '950mb', 'direction': 80, 'speed': ...
# 175    [{'layer': '950mb', 'direction': 70, 'speed': ...
# 176    [{'layer': '950mb', 'direction': 75, 'speed': ...
# 177    [{'layer': '950mb', 'direction': 75, 'speed': ...
# 178    [{'layer': '950mb', 'direction': 10, 'speed': ...
# 179    [{'layer': '950mb', 'direction': 355, 'speed':...
# 180    [{'layer': '950mb', 'direction': 350, 'speed':...
# 181    [{'layer': '950mb', 'direction': 5, 'speed': 2...
# 182    [{'layer': '950mb', 'direction': 320, 'speed':...
# 183    [{'layer': '950mb', 'direction': 325, 'speed':...
# 184    [{'layer': '950mb', 'direction': 50, 'speed': ...
# 185    [{'layer': '950mb', 'direction': 30, 'speed': ...
# 186    [{'layer': '950mb', 'direction': 20, 'speed': ...
# 187    [{'layer': '950mb', 'direction': 60, 'speed': ...
# 188    [{'layer': '950mb', 'direction': 55, 'speed': ...
# 189    [{'layer': '950mb', 'direction': 45, 'speed': ...
# 190    [{'layer': '950mb', 'direction': 30, 'speed': ...
# 191    [{'layer': '950mb', 'direction': 30, 'speed': ...
# 192    [{'layer': '950mb', 'direction': 300, 'speed':...
# 193    [{'layer': '950mb', 'direction': 330, 'speed':...
# 194    [{'layer': '950mb', 'direction': 300, 'speed':...
# 195    [{'layer': '950mb', 'direction': 270, 'speed':...
# 196    [{'layer': '950mb', 'direction': 275, 'speed':...
# 197    [{'layer': '950mb', 'direction': 255, 'speed':...
# 198    [{'layer': '950mb', 'direction': 240, 'speed':...
# 199    [{'layer': '950mb', 'direction': 215, 'speed':...
# 200    [{'layer': '950mb', 'direction': 210, 'speed':...
# 201    [{'layer': '950mb', 'direction': 205, 'speed':...
# 202    [{'layer': '950mb', 'direction': 205, 'speed':...
# 203    [{'layer': '950mb', 'direction': 210, 'speed':...
# 204    [{'layer': '950mb', 'direction': 240, 'speed':...
# 205    [{'layer': '950mb', 'direction': 245, 'speed':...
# 206    [{'layer': '950mb', 'direction': 250, 'speed':...
# 207    [{'layer': '950mb', 'direction': 240, 'speed':...
# 208    [{'layer': '950mb', 'direction': 240, 'speed':...
# 209    [{'layer': '950mb', 'direction': 240, 'speed':...
# 210    [{'layer': '950mb', 'direction': 230, 'speed':...
# 211    [{'layer': '950mb', 'direction': 225, 'speed':...
# 212    [{'layer': '950mb', 'direction': 220, 'speed':...
# 213    [{'layer': '950mb', 'direction': 225, 'speed':...
# 214    [{'layer': '950mb', 'direction': 215, 'speed':...
# 215    [{'layer': '950mb', 'direction': 210, 'speed':...
# 216    [{'layer': '950mb', 'direction': 215, 'speed':...
# 217    [{'layer': '950mb', 'direction': 215, 'speed':...
# 218    [{'layer': '950mb', 'direction': 215, 'speed':...
# 219    [{'layer': '950mb', 'direction': 210, 'speed':...
# 220    [{'layer': '950mb', 'direction': 205, 'speed':...
# 221    [{'layer': '950mb', 'direction': 245, 'speed':...
# 222    [{'layer': '950mb', 'direction': 270, 'speed':...
# 223    [{'layer': '950mb', 'direction': 320, 'speed':...
# 224    [{'layer': '950mb', 'direction': 330, 'speed':...
# 225    [{'layer': '950mb', 'direction': 335, 'speed':...
# 226    [{'layer': '950mb', 'direction': 335, 'speed':...
# 227    [{'layer': '950mb', 'direction': 330, 'speed':...
# 228    [{'layer': '950mb', 'direction': 335, 'speed':...
# 229    [{'layer': '950mb', 'direction': 330, 'speed':...
# 230    [{'layer': '950mb', 'direction': 325, 'speed':...
# 231    [{'layer': '950mb', 'direction': 330, 'speed':...
# 232    [{'layer': '950mb', 'direction': 325, 'speed':...
# 233    [{'layer': '950mb', 'direction': 330, 'speed':...
# 234    [{'layer': '950mb', 'direction': 335, 'speed':...
# 235    [{'layer': '950mb', 'direction': 335, 'speed':...
# 236    [{'layer': '950mb', 'direction': 335, 'speed':...
# 237    [{'layer': '950mb', 'direction': 340, 'speed':...
# 238    [{'layer': '950mb', 'direction': 340, 'speed':...
# 239    [{'layer': '950mb', 'direction': 340, 'speed':...
# 240    [{'layer': '950mb', 'direction': 335, 'speed':...
# 241    [{'layer': '950mb', 'direction': 340, 'speed':...
# 242    [{'layer': '950mb', 'direction': 335, 'speed':...
# 243    [{'layer': '950mb', 'direction': 330, 'speed':...
# 244    [{'layer': '950mb', 'direction': 325, 'speed':...
# 245    [{'layer': '950mb', 'direction': 320, 'speed':...
# 246    [{'layer': '950mb', 'direction': 310, 'speed':...
# 247    [{'layer': '950mb', 'direction': 295, 'speed':...
# 248    [{'layer': '950mb', 'direction': 295, 'speed':...
# 249    [{'layer': '950mb', 'direction': 285, 'speed':...
# 250    [{'layer': '950mb', 'direction': 275, 'speed':...
# 251    [{'layer': '950mb', 'direction': 225, 'speed':...
# 252    [{'layer': '950mb', 'direction': 205, 'speed':...
# 253    [{'layer': '950mb', 'direction': 195, 'speed':...
# 254    [{'layer': '950mb', 'direction': 175, 'speed':...
# 255    [{'layer': '950mb', 'direction': 150, 'speed':...
# 256    [{'layer': '950mb', 'direction': 105, 'speed':...
# 257    [{'layer': '950mb', 'direction': 105, 'speed':...
# 258    [{'layer': '950mb', 'direction': 115, 'speed':...
# 259    [{'layer': '950mb', 'direction': 105, 'speed':...
# 260    [{'layer': '950mb', 'direction': 115, 'speed':...
# 261    [{'layer': '950mb', 'direction': 115, 'speed':...
# 262    [{'layer': '950mb', 'direction': 115, 'speed':...
# 263    [{'layer': '950mb', 'direction': 115, 'speed':...
# 264    [{'layer': '950mb', 'direction': 110, 'speed':...
# 265    [{'layer': '950mb', 'direction': 110, 'speed':...
# 266    [{'layer': '950mb', 'direction': 110, 'speed':...
# 267    [{'layer': '950mb', 'direction': 110, 'speed':...
# 268    [{'layer': '950mb', 'direction': 115, 'speed':...
# 269    [{'layer': '950mb', 'direction': 120, 'speed':...
# 270    [{'layer': '950mb', 'direction': 120, 'speed':...
# 271    [{'layer': '950mb', 'direction': 130, 'speed':...
# 272    [{'layer': '950mb', 'direction': 125, 'speed':...
# 273    [{'layer': '950mb', 'direction': 125, 'speed':...
# 274    [{'layer': '950mb', 'direction': 125, 'speed':...
# 275    [{'layer': '950mb', 'direction': 125, 'speed':...
# 276    [{'layer': '950mb', 'direction': 120, 'speed':...
# 277    [{'layer': '950mb', 'direction': 120, 'speed':...
# 278    [{'layer': '950mb', 'direction': 120, 'speed':...
# 279    [{'layer': '950mb', 'direction': 115, 'speed':...
# 280    [{'layer': '950mb', 'direction': 115, 'speed':...
# 281    [{'layer': '950mb', 'direction': 115, 'speed':...
# 282    [{'layer': '950mb', 'direction': 115, 'speed':...
# 283    [{'layer': '950mb', 'direction': 110, 'speed':...
# 284    [{'layer': '950mb', 'direction': 110, 'speed':...
# 285    [{'layer': '950mb', 'direction': 110, 'speed':...
# 286    [{'layer': '950mb', 'direction': 110, 'speed':...
# 287    [{'layer': '950mb', 'direction': 105, 'speed':...
# 288    [{'layer': '950mb', 'direction': 100, 'speed':...
# 289    [{'layer': '950mb', 'direction': 100, 'speed':...
# 290    [{'layer': '950mb', 'direction': 95, 'speed': ...
# 291    [{'layer': '950mb', 'direction': 95, 'speed': ...
# 292    [{'layer': '950mb', 'direction': 95, 'speed': ...
# 293    [{'layer': '950mb', 'direction': 95, 'speed': ...
# 294    [{'layer': '950mb', 'direction': 95, 'speed': ...
# 295    [{'layer': '950mb', 'direction': 100, 'speed':...
# 296    [{'layer': '950mb', 'direction': 100, 'speed':...
# 297    [{'layer': '950mb', 'direction': 100, 'speed':...
# 298    [{'layer': '950mb', 'direction': 100, 'speed':...
# 299    [{'layer': '950mb', 'direction': 100, 'speed':...
# 300    [{'layer': '950mb', 'direction': 95, 'speed': ...
# 301    [{'layer': '950mb', 'direction': 90, 'speed': ...
# 302    [{'layer': '950mb', 'direction': 95, 'speed': ...
# 303    [{'layer': '950mb', 'direction': 95, 'speed': ...
# 304    [{'layer': '950mb', 'direction': 95, 'speed': ...
# 305    [{'layer': '950mb', 'direction': 95, 'speed': ...
# 306    [{'layer': '950mb', 'direction': 90, 'speed': ...
# 307    [{'layer': '950mb', 'direction': 95, 'speed': ...
# 308    [{'layer': '950mb', 'direction': 95, 'speed': ...
# 309    [{'layer': '950mb', 'direction': 95, 'speed': ...
# 310    [{'layer': '950mb', 'direction': 100, 'speed':...
# 311    [{'layer': '950mb', 'direction': 95, 'speed': ...
# 312    [{'layer': '950mb', 'direction': 100, 'speed':...
# 313    [{'layer': '950mb', 'direction': 100, 'speed':...
# 314    [{'layer': '950mb', 'direction': 100, 'speed':...
# 315    [{'layer': '950mb', 'direction': 100, 'speed':...
# 316    [{'layer': '950mb', 'direction': 95, 'speed': ...
# 317    [{'layer': '950mb', 'direction': 90, 'speed': ...
# 318    [{'layer': '950mb', 'direction': 95, 'speed': ...
# 319    [{'layer': '950mb', 'direction': 100, 'speed':...
# Name: wind_profile, dtype: object

# %% [markdown]
# ##### Vamos primero con la columna `rh_profile`

# %%
# Entendiendo las series, razonamos y probamos que, cuando le damos una lista a una serie la ordena con indices, que serán las columnas de un dataframe. 
# Los values de la serie serán los elementos de la lista, que serán los registros de una sola de las filas para cada columna de un dataframe.
# Por lo tanto, si aplicamos un pd.Series a cada fila, nos convertirá esa lista en un conjunto de columnas ordenadas por un índice asignado, y cada value será cada valor de la fila. 
df_rh_layer = df_clima['rh_profile'].apply(pd.Series)
df_rh_layer.head()
# Out:
#                             0                            1   \
# 0  {'layer': '950mb', 'rh': 4}  {'layer': '900mb', 'rh': 5}
# 1  {'layer': '950mb', 'rh': 3}  {'layer': '900mb', 'rh': 5}
# 2  {'layer': '950mb', 'rh': 4}  {'layer': '900mb', 'rh': 4}
# 3  {'layer': '950mb', 'rh': 5}  {'layer': '900mb', 'rh': 6}
# 4  {'layer': '950mb', 'rh': 6}  {'layer': '900mb', 'rh': 4}
#
#                             2                             3   \
# 0  {'layer': '850mb', 'rh': 6}   {'layer': '800mb', 'rh': 7}
# 1  {'layer': '850mb', 'rh': 6}   {'layer': '800mb', 'rh': 8}
# 2  {'layer': '850mb', 'rh': 6}   {'layer': '800mb', 'rh': 8}
# 3  {'layer': '850mb', 'rh': 7}   {'layer': '800mb', 'rh': 9}
# 4  {'layer': '850mb', 'rh': 7}  {'layer': '800mb', 'rh': 10}
#
#                              4                             5   \
# 0   {'layer': '750mb', 'rh': 8}  {'layer': '700mb', 'rh': 11}
# 1   {'layer': '750mb', 'rh': 8}  {'layer': '700mb', 'rh': 10}
# 2  {'layer': '750mb', 'rh': 11}  {'layer': '700mb', 'rh': 10}
# 3  {'layer': '750mb', 'rh': 11}  {'layer': '700mb', 'rh': 13}
# 4  {'layer': '750mb', 'rh': 13}  {'layer': '700mb', 'rh': 13}
#
#                              6                            7   \
# 0  {'layer': '650mb', 'rh': 11}  {'layer': '600mb', 'rh': 6}
# 1  {'layer': '650mb', 'rh': 10}  {'layer': '600mb', 'rh': 9}
# 2   {'layer': '650mb', 'rh': 8}  {'layer': '600mb', 'rh': 8}
# 3  {'layer': '650mb', 'rh': 10}  {'layer': '600mb', 'rh': 8}
# 4  {'layer': '650mb', 'rh': 10}  {'layer': '600mb', 'rh': 9}
#
#                             8                            9   \
# 0  {'layer': '550mb', 'rh': 3}  {'layer': '500mb', 'rh': 1}
# 1  {'layer': '550mb', 'rh': 5}  {'layer': '500mb', 'rh': 5}
# 2  {'layer': '550mb', 'rh': 7}  {'layer': '500mb', 'rh': 8}
# 3  {'layer': '550mb', 'rh': 8}  {'layer': '500mb', 'rh': 7}
# 4  {'layer': '550mb', 'rh': 8}  {'layer': '500mb', 'rh': 6}
#
#                              10                           11  \
# 0   {'layer': '450mb', 'rh': 6}  {'layer': '400mb', 'rh': 7}
# 1  {'layer': '450mb', 'rh': 10}  {'layer': '400mb', 'rh': 9}
# 2   {'layer': '450mb', 'rh': 7}  {'layer': '400mb', 'rh': 3}
# 3   {'layer': '450mb', 'rh': 4}  {'layer': '400mb', 'rh': 3}
# 4   {'layer': '450mb', 'rh': 4}  {'layer': '400mb', 'rh': 4}
#
#                             12                            13  \
# 0  {'layer': '350mb', 'rh': 5}  {'layer': '300mb', 'rh': 11}
# 1  {'layer': '350mb', 'rh': 9}   {'layer': '300mb', 'rh': 7}
# 2  {'layer': '350mb', 'rh': 2}   {'layer': '300mb', 'rh': 3}
# 3  {'layer': '350mb', 'rh': 2}   {'layer': '300mb', 'rh': 6}
# 4  {'layer': '350mb', 'rh': 8}   {'layer': '300mb', 'rh': 4}
#
#                              14                            15
# 0   {'layer': '250mb', 'rh': 6}  {'layer': '200mb', 'rh': -2}
# 1   {'layer': '250mb', 'rh': 4}  {'layer': '200mb', 'rh': -3}
# 2   {'layer': '250mb', 'rh': 6}  {'layer': '200mb', 'rh': -3}
# 3  {'layer': '250mb', 'rh': 12}  {'layer': '200mb', 'rh': -3}
# 4   {'layer': '250mb', 'rh': 6}  {'layer': '200mb', 'rh': -3}

# %%
# Queremos extraer de los diccionarios el nombre de cada columna y el value de cada columna y fila.
# Hacemos un for loop. Aportamos el proceso razonado al final del jupyter.

df_limpio_layers = pd.DataFrame()

for col in range(len(df_rh_layer.columns)):
    # Volvemos a aplicar pd.Series a cada fila, ya que convertirá los keys en columnas y los values en filas 
    # y es una de las maneras posibles para extraer su contenido
    desempaque_dicc = df_rh_layer[col].apply(pd.Series)
    
    layer = desempaque_dicc.iloc[0].index[0]
    num = desempaque_dicc.iloc[0].values[0]
    #Construimos el nombre de la columna
    nom = 'rh_'+ layer + '_' + num

    # Creamos una lista que será el contenido de cada columna creada en este loop   
    lista = []
    for fila in range(len(desempaque_dicc.index)):
        
        value = desempaque_dicc.iloc[fila].values[1]
        lista.append(value)

    # Terminamos el loop rellenando nuestro df vacío con el contenido extraído
    df_limpio_layers[nom] = lista

# %%
# Reseteamos el indice para el siguiente paso
df_limpio_layers.reset_index(inplace=True)
df_limpio_layers.head()
# Out:
#    index  rh_layer_950mb  rh_layer_900mb  rh_layer_850mb  rh_layer_800mb  \
# 0      0               4               5               6               7
# 1      1               3               5               6               8
# 2      2               4               4               6               8
# 3      3               5               6               7               9
# 4      4               6               4               7              10
#
#    rh_layer_750mb  rh_layer_700mb  rh_layer_650mb  rh_layer_600mb  \
# 0               8              11              11               6
# 1               8              10              10               9
# 2              11              10               8               8
# 3              11              13              10               8
# 4              13              13              10               9
#
#    rh_layer_550mb  rh_layer_500mb  rh_layer_450mb  rh_layer_400mb  \
# 0               3               1               6               7
# 1               5               5              10               9
# 2               7               8               7               3
# 3               8               7               4               3
# 4               8               6               4               4
#
#    rh_layer_350mb  rh_layer_300mb  rh_layer_250mb  rh_layer_200mb
# 0               5              11               6              -2
# 1               9               7               4              -3
# 2               2               3               6              -3
# 3               2               6              12              -3
# 4               8               4               6              -3

# %% [markdown]
# ##### Mergeamos con el df_clima

# %%
# Hacemos lo mismo con el df clima
df_clima.reset_index(inplace=True)

# %%
# Mergeamos por los indices
df_clima2 = df_clima.merge(df_limpio_layers, on= ['index'] )
df_clima2.head(1)
# Out:
#    index  timepoint  cloudcover  highcloud  midcloud  lowcloud  \
# 0      0          3           1      -9999     -9999     -9999
#
#                                           rh_profile  \
# 0  [{'layer': '950mb', 'rh': 4}, {'layer': '900mb...
#
#                                         wind_profile  temp2m  lifted_index  \
# 0  [{'layer': '950mb', 'direction': 155, 'speed':...      27             2
#
#    rh2m  msl_pressure prec_type  prec_amount  snow_depth wind10m.direction  \
# 0     2          1011      none            0           0               190
#
#    wind10m.speed pais   latitud    longitud  rh_layer_950mb  rh_layer_900mb  \
# 0              2  usa  39.78373 -100.445882               4               5
#
#    rh_layer_850mb  rh_layer_800mb  rh_layer_750mb  rh_layer_700mb  \
# 0               6               7               8              11
#
#    rh_layer_650mb  rh_layer_600mb  rh_layer_550mb  rh_layer_500mb  \
# 0              11               6               3               1
#
#    rh_layer_450mb  rh_layer_400mb  rh_layer_350mb  rh_layer_300mb  \
# 0               6               7               5              11
#
#    rh_layer_250mb  rh_layer_200mb
# 0               6              -2

# %%
# Eliminamos la columna rh_profile
df_clima2.drop(['rh_profile'], axis=1, inplace=True)
df_clima2.head(1)
# Out:
#    index  timepoint  cloudcover  highcloud  midcloud  lowcloud  \
# 0      0          3           1      -9999     -9999     -9999
#
#                                         wind_profile  temp2m  lifted_index  \
# 0  [{'layer': '950mb', 'direction': 155, 'speed':...      27             2
#
#    rh2m  msl_pressure prec_type  prec_amount  snow_depth wind10m.direction  \
# 0     2          1011      none            0           0               190
#
#    wind10m.speed pais   latitud    longitud  rh_layer_950mb  rh_layer_900mb  \
# 0              2  usa  39.78373 -100.445882               4               5
#
#    rh_layer_850mb  rh_layer_800mb  rh_layer_750mb  rh_layer_700mb  \
# 0               6               7               8              11
#
#    rh_layer_650mb  rh_layer_600mb  rh_layer_550mb  rh_layer_500mb  \
# 0              11               6               3               1
#
#    rh_layer_450mb  rh_layer_400mb  rh_layer_350mb  rh_layer_300mb  \
# 0               6               7               5              11
#
#    rh_layer_250mb  rh_layer_200mb
# 0               6              -2

# %% [markdown]
# ##### Vamos con la columna `wind_profile`

# %%
# Aplicamos pd.Series a cada fila
# Vemos que en vez de tener dos variables tenemos 3
df_wind = df_clima['wind_profile'].apply(pd.Series)
df_wind.head()
# Out:
#                                                  0   \
# 0  {'layer': '950mb', 'direction': 155, 'speed': 2}
# 1  {'layer': '950mb', 'direction': 155, 'speed': 2}
# 2  {'layer': '950mb', 'direction': 120, 'speed': 3}
# 3  {'layer': '950mb', 'direction': 110, 'speed': 2}
# 4  {'layer': '950mb', 'direction': 265, 'speed': 2}
#
#                                                  1   \
# 0  {'layer': '900mb', 'direction': 145, 'speed': 3}
# 1  {'layer': '900mb', 'direction': 185, 'speed': 2}
# 2  {'layer': '900mb', 'direction': 145, 'speed': 2}
# 3  {'layer': '900mb', 'direction': 105, 'speed': 2}
# 4   {'layer': '900mb', 'direction': 35, 'speed': 2}
#
#                                                  2   \
# 0  {'layer': '850mb', 'direction': 160, 'speed': 3}
# 1  {'layer': '850mb', 'direction': 230, 'speed': 2}
# 2  {'layer': '850mb', 'direction': 245, 'speed': 2}
# 3  {'layer': '850mb', 'direction': 160, 'speed': 2}
# 4   {'layer': '850mb', 'direction': 80, 'speed': 2}
#
#                                                  3   \
# 0  {'layer': '800mb', 'direction': 230, 'speed': 2}
# 1  {'layer': '800mb', 'direction': 235, 'speed': 3}
# 2  {'layer': '800mb', 'direction': 260, 'speed': 3}
# 3  {'layer': '800mb', 'direction': 230, 'speed': 2}
# 4  {'layer': '800mb', 'direction': 250, 'speed': 2}
#
#                                                  4   \
# 0  {'layer': '750mb', 'direction': 250, 'speed': 3}
# 1  {'layer': '750mb', 'direction': 250, 'speed': 3}
# 2  {'layer': '750mb', 'direction': 275, 'speed': 3}
# 3  {'layer': '750mb', 'direction': 255, 'speed': 3}
# 4  {'layer': '750mb', 'direction': 270, 'speed': 2}
#
#                                                  5   \
# 0  {'layer': '700mb', 'direction': 260, 'speed': 3}
# 1  {'layer': '700mb', 'direction': 255, 'speed': 3}
# 2  {'layer': '700mb', 'direction': 270, 'speed': 3}
# 3  {'layer': '700mb', 'direction': 275, 'speed': 4}
# 4  {'layer': '700mb', 'direction': 270, 'speed': 3}
#
#                                                  6   \
# 0  {'layer': '650mb', 'direction': 250, 'speed': 4}
# 1  {'layer': '650mb', 'direction': 240, 'speed': 3}
# 2  {'layer': '650mb', 'direction': 245, 'speed': 3}
# 3  {'layer': '650mb', 'direction': 280, 'speed': 3}
# 4  {'layer': '650mb', 'direction': 270, 'speed': 3}
#
#                                                  7   \
# 0  {'layer': '600mb', 'direction': 240, 'speed': 4}
# 1  {'layer': '600mb', 'direction': 230, 'speed': 4}
# 2  {'layer': '600mb', 'direction': 240, 'speed': 4}
# 3  {'layer': '600mb', 'direction': 245, 'speed': 3}
# 4  {'layer': '600mb', 'direction': 250, 'speed': 3}
#
#                                                  8   \
# 0  {'layer': '550mb', 'direction': 235, 'speed': 5}
# 1  {'layer': '550mb', 'direction': 235, 'speed': 5}
# 2  {'layer': '550mb', 'direction': 245, 'speed': 4}
# 3  {'layer': '550mb', 'direction': 250, 'speed': 4}
# 4  {'layer': '550mb', 'direction': 245, 'speed': 3}
#
#                                                  9   \
# 0  {'layer': '500mb', 'direction': 235, 'speed': 5}
# 1  {'layer': '500mb', 'direction': 235, 'speed': 5}
# 2  {'layer': '500mb', 'direction': 250, 'speed': 5}
# 3  {'layer': '500mb', 'direction': 245, 'speed': 4}
# 4  {'layer': '500mb', 'direction': 240, 'speed': 3}
#
#                                                  10  \
# 0  {'layer': '450mb', 'direction': 235, 'speed': 5}
# 1  {'layer': '450mb', 'direction': 240, 'speed': 5}
# 2  {'layer': '450mb', 'direction': 245, 'speed': 5}
# 3  {'layer': '450mb', 'direction': 240, 'speed': 4}
# 4  {'layer': '450mb', 'direction': 245, 'speed': 3}
#
#                                                  11  \
# 0  {'layer': '400mb', 'direction': 235, 'speed': 5}
# 1  {'layer': '400mb', 'direction': 245, 'speed': 5}
# 2  {'layer': '400mb', 'direction': 245, 'speed': 5}
# 3  {'layer': '400mb', 'direction': 245, 'speed': 4}
# 4  {'layer': '400mb', 'direction': 245, 'speed': 4}
#
#                                                  12  \
# 0  {'layer': '350mb', 'direction': 230, 'speed': 5}
# 1  {'layer': '350mb', 'direction': 250, 'speed': 5}
# 2  {'layer': '350mb', 'direction': 255, 'speed': 5}
# 3  {'layer': '350mb', 'direction': 245, 'speed': 5}
# 4  {'layer': '350mb', 'direction': 245, 'speed': 4}
#
#                                                  13  \
# 0  {'layer': '300mb', 'direction': 235, 'speed': 6}
# 1  {'layer': '300mb', 'direction': 250, 'speed': 6}
# 2  {'layer': '300mb', 'direction': 250, 'speed': 5}
# 3  {'layer': '300mb', 'direction': 245, 'speed': 5}
# 4  {'layer': '300mb', 'direction': 250, 'speed': 5}
#
#                                                  14  \
# 0  {'layer': '250mb', 'direction': 230, 'speed': 7}
# 1  {'layer': '250mb', 'direction': 240, 'speed': 6}
# 2  {'layer': '250mb', 'direction': 245, 'speed': 5}
# 3  {'layer': '250mb', 'direction': 255, 'speed': 5}
# 4  {'layer': '250mb', 'direction': 245, 'speed': 5}
#
#                                                  15
# 0  {'layer': '200mb', 'direction': 235, 'speed': 7}
# 1  {'layer': '200mb', 'direction': 250, 'speed': 6}
# 2  {'layer': '200mb', 'direction': 255, 'speed': 6}
# 3  {'layer': '200mb', 'direction': 255, 'speed': 6}
# 4  {'layer': '200mb', 'direction': 255, 'speed': 5}

# %%
# Probando con un elemento se nos ocurre crear dos columnas por cada columna con nombres: layer 950mb direction y layer 950mb speed, etc.
df_wind[0].apply(pd.Series)
# Out:
#      layer  direction  speed
# 0    950mb        155      2
# 1    950mb        155      2
# 2    950mb        120      3
# 3    950mb        110      2
# 4    950mb        265      2
# 5    950mb        320      2
# 6    950mb        335      2
# 7    950mb        355      2
# 8    950mb         10      2
# 9    950mb        110      2
# 10   950mb        170      2
# 11   950mb        205      2
# 12   950mb        200      2
# 13   950mb        230      2
# 14   950mb        240      2
# 15   950mb        300      2
# 16   950mb        250      2
# 17   950mb        165      3
# 18   950mb        105      3
# 19   950mb        140      2
# 20   950mb        155      2
# 21   950mb        105      2
# 22   950mb        105      2
# 23   950mb        160      2
# 24   950mb        165      2
# 25   950mb        185      2
# 26   950mb        200      2
# 27   950mb        185      2
# 28   950mb        200      2
# 29   950mb        190      2
# 30   950mb        205      2
# 31   950mb        295      2
# 32   950mb        110      2
# 33   950mb        130      2
# 34   950mb        155      3
# 35   950mb        170      2
# 36   950mb        175      2
# 37   950mb        190      2
# 38   950mb        160      2
# 39   950mb        100      2
# 40   950mb        155      2
# 41   950mb        165      3
# 42   950mb        155      3
# 43   950mb        180      2
# 44   950mb        195      3
# 45   950mb        200      2
# 46   950mb        190      2
# 47   950mb        210      2
# 48   950mb        190      2
# 49   950mb        175      2
# 50   950mb        165      3
# 51   950mb        155      3
# 52   950mb        205      2
# 53   950mb        190      2
# 54   950mb         10      1
# 55   950mb         65      2
# 56   950mb         95      2
# 57   950mb        120      2
# 58   950mb        115      2
# 59   950mb        110      2
# 60   950mb        125      2
# 61   950mb        130      2
# 62   950mb        135      2
# 63   950mb        270      1
# 64   950mb        165      4
# 65   950mb        170      5
# 66   950mb        165      5
# 67   950mb        155      5
# 68   950mb        150      5
# 69   950mb        155      5
# 70   950mb        145      5
# 71   950mb        150      5
# 72   950mb        145      4
# 73   950mb        145      4
# 74   950mb        140      4
# 75   950mb        140      4
# 76   950mb        135      4
# 77   950mb        120      4
# 78   950mb        110      4
# 79   950mb         95      4
# 80   950mb         90      3
# 81   950mb        100      3
# 82   950mb        105      3
# 83   950mb        105      4
# 84   950mb        105      4
# 85   950mb        100      4
# 86   950mb        105      4
# 87   950mb         95      4
# 88   950mb         85      3
# 89   950mb         85      3
# 90   950mb         85      3
# 91   950mb         85      3
# 92   950mb         70      3
# 93   950mb         65      3
# 94   950mb         60      3
# 95   950mb         50      3
# 96   950mb         40      3
# 97   950mb         40      3
# 98   950mb         40      3
# 99   950mb         55      3
# 100  950mb         65      3
# 101  950mb         65      2
# 102  950mb         65      3
# 103  950mb         50      3
# 104  950mb         55      3
# 105  950mb         60      3
# 106  950mb         75      3
# 107  950mb         85      3
# 108  950mb         80      3
# 109  950mb        100      3
# 110  950mb        110      3
# 111  950mb        105      3
# 112  950mb         90      3
# 113  950mb         90      3
# 114  950mb         90      4
# 115  950mb         90      4
# 116  950mb         85      4
# 117  950mb         90      4
# 118  950mb         95      4
# 119  950mb         95      4
# 120  950mb         95      4
# 121  950mb         95      3
# 122  950mb         95      3
# 123  950mb         85      4
# 124  950mb         75      3
# 125  950mb         80      3
# 126  950mb         75      3
# 127  950mb         75      3
# 128  950mb         35      4
# 129  950mb         20      5
# 130  950mb          0      5
# 131  950mb        320      5
# 132  950mb        310      5
# 133  950mb        305      5
# 134  950mb        295      5
# 135  950mb        260      4
# 136  950mb        260      3
# 137  950mb        270      3
# 138  950mb        270      3
# 139  950mb        260      3
# 140  950mb        285      3
# 141  950mb        290      3
# 142  950mb        305      3
# 143  950mb        305      3
# 144  950mb        300      3
# 145  950mb        320      3
# 146  950mb        325      3
# 147  950mb        300      3
# 148  950mb        325      3
# 149  950mb        350      3
# 150  950mb         25      3
# 151  950mb        355      3
# 152  950mb         10      4
# 153  950mb        350      4
# 154  950mb        340      4
# 155  950mb        345      3
# 156  950mb         35      3
# 157  950mb         30      3
# 158  950mb        320      3
# 159  950mb        325      3
# 160  950mb        285      3
# 161  950mb        235      2
# 162  950mb        210      2
# 163  950mb        175      2
# 164  950mb        200      3
# 165  950mb        200      3
# 166  950mb        205      3
# 167  950mb        165      3
# 168  950mb        120      3
# 169  950mb        115      3
# 170  950mb        115      3
# 171  950mb        105      3
# 172  950mb         85      3
# 173  950mb         90      3
# 174  950mb         80      3
# 175  950mb         70      3
# 176  950mb         75      3
# 177  950mb         75      4
# 178  950mb         10      3
# 179  950mb        355      3
# 180  950mb        350      2
# 181  950mb          5      2
# 182  950mb        320      2
# 183  950mb        325      2
# 184  950mb         50      2
# 185  950mb         30      2
# 186  950mb         20      2
# 187  950mb         60      2
# 188  950mb         55      3
# 189  950mb         45      3
# 190  950mb         30      3
# 191  950mb         30      4
# 192  950mb        300      3
# 193  950mb        330      3
# 194  950mb        300      3
# 195  950mb        270      3
# 196  950mb        275      4
# 197  950mb        255      5
# 198  950mb        240      5
# 199  950mb        215      5
# 200  950mb        210      5
# 201  950mb        205      4
# 202  950mb        205      3
# 203  950mb        210      3
# 204  950mb        240      3
# 205  950mb        245      3
# 206  950mb        250      3
# 207  950mb        240      3
# 208  950mb        240      3
# 209  950mb        240      4
# 210  950mb        230      4
# 211  950mb        225      4
# 212  950mb        220      4
# 213  950mb        225      4
# 214  950mb        215      4
# 215  950mb        210      4
# 216  950mb        215      3
# 217  950mb        215      3
# 218  950mb        215      3
# 219  950mb        210      3
# 220  950mb        205      2
# 221  950mb        245      2
# 222  950mb        270      2
# 223  950mb        320      2
# 224  950mb        330      3
# 225  950mb        335      3
# 226  950mb        335      3
# 227  950mb        330      3
# 228  950mb        335      3
# 229  950mb        330      4
# 230  950mb        325      4
# 231  950mb        330      4
# 232  950mb        325      4
# 233  950mb        330      4
# 234  950mb        335      4
# 235  950mb        335      4
# 236  950mb        335      5
# 237  950mb        340      5
# 238  950mb        340      5
# 239  950mb        340      5
# 240  950mb        335      5
# 241  950mb        340      5
# 242  950mb        335      5
# 243  950mb        330      5
# 244  950mb        325      5
# 245  950mb        320      6
# 246  950mb        310      5
# 247  950mb        295      5
# 248  950mb        295      4
# 249  950mb        285      4
# 250  950mb        275      3
# 251  950mb        225      3
# 252  950mb        205      3
# 253  950mb        195      3
# 254  950mb        175      3
# 255  950mb        150      3
# 256  950mb        105      4
# 257  950mb        105      4
# 258  950mb        115      4
# 259  950mb        105      5
# 260  950mb        115      4
# 261  950mb        115      4
# 262  950mb        115      4
# 263  950mb        115      4
# 264  950mb        110      4
# 265  950mb        110      4
# 266  950mb        110      4
# 267  950mb        110      4
# 268  950mb        115      4
# 269  950mb        120      4
# 270  950mb        120      4
# 271  950mb        130      4
# 272  950mb        125      4
# 273  950mb        125      4
# 274  950mb        125      4
# 275  950mb        125      4
# 276  950mb        120      4
# 277  950mb        120      4
# 278  950mb        120      4
# 279  950mb        115      4
# 280  950mb        115      4
# 281  950mb        115      4
# 282  950mb        115      4
# 283  950mb        110      4
# 284  950mb        110      4
# 285  950mb        110      4
# 286  950mb        110      4
# 287  950mb        105      4
# 288  950mb        100      4
# 289  950mb        100      4
# 290  950mb         95      4
# 291  950mb         95      4
# 292  950mb         95      4
# 293  950mb         95      4
# 294  950mb         95      4
# 295  950mb        100      4
# 296  950mb        100      4
# 297  950mb        100      4
# 298  950mb        100      4
# 299  950mb        100      4
# 300  950mb         95      4
# 301  950mb         90      4
# 302  950mb         95      4
# 303  950mb         95      5
# 304  950mb         95      4
# 305  950mb         95      5
# 306  950mb         90      5
# 307  950mb         95      5
# 308  950mb         95      5
# 309  950mb         95      4
# 310  950mb        100      4
# 311  950mb         95      4
# 312  950mb        100      4
# 313  950mb        100      4
# 314  950mb        100      4
# 315  950mb        100      4
# 316  950mb         95      4
# 317  950mb         90      4
# 318  950mb         95      4
# 319  950mb        100      4

# %%
# Hacemos un for loop
df_limpio_wind = pd.DataFrame()

for col in range(len(df_wind.columns)):
    # Volvemos a aplicar pd.Series a cada fila, ya que convertirá los keys en columnas y los values en filas 
    desempaq_dicc = df_wind[col].apply(pd.Series)
    
    layer = desempaq_dicc.iloc[0,:].index[0]
    num = desempaq_dicc.iloc[0,:].values[0]
    direction = desempaq_dicc.iloc[0,:].index[1]
    speed = desempaq_dicc.iloc[0,:].index[2]
    
    #Construimos el nombre de las columnas
    nom1 = layer + num + '_' + direction
    nom2 = layer + num + '_' + speed

    # Creamos una lista que será el contenido de cada columna creada en este loop   
    lista1 = []
    lista2 = []
    for fila in range(len(desempaq_dicc.index)):

        value_dir = desempaq_dicc.iloc[fila,:].values[1]
        value_sp= desempaq_dicc.iloc[fila,:].values[2]
        
        lista1.append(value_dir)
        lista2.append(value_sp)

    # Terminamos el loop rellenando nuestro df vacío con el contenido extraído
    df_limpio_wind[nom1] = lista1
    df_limpio_wind[nom2] = lista2

# %%
# Reseteamos el índice para el siguiente paso
df_limpio_wind.reset_index(inplace=True)
df_limpio_wind.head()
# Out:
#    index  layer950mb_direction  layer950mb_speed  layer900mb_direction  \
# 0      0                   155                 2                   145
# 1      1                   155                 2                   185
# 2      2                   120                 3                   145
# 3      3                   110                 2                   105
# 4      4                   265                 2                    35
#
#    layer900mb_speed  layer850mb_direction  layer850mb_speed  \
# 0                 3                   160                 3
# 1                 2                   230                 2
# 2                 2                   245                 2
# 3                 2                   160                 2
# 4                 2                    80                 2
#
#    layer800mb_direction  layer800mb_speed  layer750mb_direction  \
# 0                   230                 2                   250
# 1                   235                 3                   250
# 2                   260                 3                   275
# 3                   230                 2                   255
# 4                   250                 2                   270
#
#    layer750mb_speed  layer700mb_direction  layer700mb_speed  \
# 0                 3                   260                 3
# 1                 3                   255                 3
# 2                 3                   270                 3
# 3                 3                   275                 4
# 4                 2                   270                 3
#
#    layer650mb_direction  layer650mb_speed  layer600mb_direction  \
# 0                   250                 4                   240
# 1                   240                 3                   230
# 2                   245                 3                   240
# 3                   280                 3                   245
# 4                   270                 3                   250
#
#    layer600mb_speed  layer550mb_direction  layer550mb_speed  \
# 0                 4                   235                 5
# 1                 4                   235                 5
# 2                 4                   245                 4
# 3                 3                   250                 4
# 4                 3                   245                 3
#
#    layer500mb_direction  layer500mb_speed  layer450mb_direction  \
# 0                   235                 5                   235
# 1                   235                 5                   240
# 2                   250                 5                   245
# 3                   245                 4                   240
# 4                   240                 3                   245
#
#    layer450mb_speed  layer400mb_direction  layer400mb_speed  \
# 0                 5                   235                 5
# 1                 5                   245                 5
# 2                 5                   245                 5
# 3                 4                   245                 4
# 4                 3                   245                 4
#
#    layer350mb_direction  layer350mb_speed  layer300mb_direction  \
# 0                   230                 5                   235
# 1                   250                 5                   250
# 2                   255                 5                   250
# 3                   245                 5                   245
# 4                   245                 4                   250
#
#    layer300mb_speed  layer250mb_direction  layer250mb_speed  \
# 0                 6                   230                 7
# 1                 6                   240                 6
# 2                 5                   245                 5
# 3                 5                   255                 5
# 4                 5                   245                 5
#
#    layer200mb_direction  layer200mb_speed
# 0                   235                 7
# 1                   250                 6
# 2                   255                 6
# 3                   255                 6
# 4                   255                 5

# %%
# Celebramos

# %% [markdown]
# ##### Mergeamos con  el df_clima2

# %%
df_clima3 = df_clima2.merge(df_limpio_wind, on= ['index'])
df_clima3.head(1)
# Out:
#    index  timepoint  cloudcover  highcloud  midcloud  lowcloud  \
# 0      0          3           1      -9999     -9999     -9999
#
#                                         wind_profile  temp2m  lifted_index  \
# 0  [{'layer': '950mb', 'direction': 155, 'speed':...      27             2
#
#    rh2m  msl_pressure prec_type  prec_amount  snow_depth wind10m.direction  \
# 0     2          1011      none            0           0               190
#
#    wind10m.speed pais   latitud    longitud  rh_layer_950mb  rh_layer_900mb  \
# 0              2  usa  39.78373 -100.445882               4               5
#
#    rh_layer_850mb  rh_layer_800mb  rh_layer_750mb  rh_layer_700mb  \
# 0               6               7               8              11
#
#    rh_layer_650mb  rh_layer_600mb  rh_layer_550mb  rh_layer_500mb  \
# 0              11               6               3               1
#
#    rh_layer_450mb  rh_layer_400mb  rh_layer_350mb  rh_layer_300mb  \
# 0               6               7               5              11
#
#    rh_layer_250mb  rh_layer_200mb  layer950mb_direction  layer950mb_speed  \
# 0               6              -2                   155                 2
#
#    layer900mb_direction  layer900mb_speed  layer850mb_direction  \
# 0                   145                 3                   160
#
#    layer850mb_speed  layer800mb_direction  layer800mb_speed  \
# 0                 3                   230                 2
#
#    layer750mb_direction  layer750mb_speed  layer700mb_direction  \
# 0                   250                 3                   260
#
#    layer700mb_speed  layer650mb_direction  layer650mb_speed  \
# 0                 3                   250                 4
#
#    layer600mb_direction  layer600mb_speed  layer550mb_direction  \
# 0                   240                 4                   235
#
#    layer550mb_speed  layer500mb_direction  layer500mb_speed  \
# 0                 5                   235                 5
#
#    layer450mb_direction  layer450mb_speed  layer400mb_direction  \
# 0                   235                 5                   235
#
#    layer400mb_speed  layer350mb_direction  layer350mb_speed  \
# 0                 5                   230                 5
#
#    layer300mb_direction  layer300mb_speed  layer250mb_direction  \
# 0                   235                 6                   230
#
#    layer250mb_speed  layer200mb_direction  layer200mb_speed
# 0                 7                   235                 7

# %%
# Eliminamos la columna wind_profile e index
df_clima3.drop(['index', 'wind_profile'], axis=1, inplace=True)
df_clima3.head(1)
# Out:
#    timepoint  cloudcover  highcloud  midcloud  lowcloud  temp2m  lifted_index  \
# 0          3           1      -9999     -9999     -9999      27             2
#
#    rh2m  msl_pressure prec_type  prec_amount  snow_depth wind10m.direction  \
# 0     2          1011      none            0           0               190
#
#    wind10m.speed pais   latitud    longitud  rh_layer_950mb  rh_layer_900mb  \
# 0              2  usa  39.78373 -100.445882               4               5
#
#    rh_layer_850mb  rh_layer_800mb  rh_layer_750mb  rh_layer_700mb  \
# 0               6               7               8              11
#
#    rh_layer_650mb  rh_layer_600mb  rh_layer_550mb  rh_layer_500mb  \
# 0              11               6               3               1
#
#    rh_layer_450mb  rh_layer_400mb  rh_layer_350mb  rh_layer_300mb  \
# 0               6               7               5              11
#
#    rh_layer_250mb  rh_layer_200mb  layer950mb_direction  layer950mb_speed  \
# 0               6              -2                   155                 2
#
#    layer900mb_direction  layer900mb_speed  layer850mb_direction  \
# 0                   145                 3                   160
#
#    layer850mb_speed  layer800mb_direction  layer800mb_speed  \
# 0                 3                   230                 2
#
#    layer750mb_direction  layer750mb_speed  layer700mb_direction  \
# 0                   250                 3                   260
#
#    layer700mb_speed  layer650mb_direction  layer650mb_speed  \
# 0                 3                   250                 4
#
#    layer600mb_direction  layer600mb_speed  layer550mb_direction  \
# 0                   240                 4                   235
#
#    layer550mb_speed  layer500mb_direction  layer500mb_speed  \
# 0                 5                   235                 5
#
#    layer450mb_direction  layer450mb_speed  layer400mb_direction  \
# 0                   235                 5                   235
#
#    layer400mb_speed  layer350mb_direction  layer350mb_speed  \
# 0                 5                   230                 5
#
#    layer300mb_direction  layer300mb_speed  layer250mb_direction  \
# 0                   235                 6                   230
#
#    layer250mb_speed  layer200mb_direction  layer200mb_speed
# 0                 7                   235                 7

# %% [markdown]
# ##### Agrupamos por paises y calculamos la media para cada columna

# %%
df_grupo_clima = df_clima3.groupby('pais').mean()
df_grupo_clima.head()
# Out:
#                   timepoint  cloudcover  highcloud  midcloud  lowcloud  \
# pais
# australia              97.5    4.187500    -9999.0   -9999.0   -9999.0
# new zealand            97.5    6.781250    -9999.0   -9999.0   -9999.0
# papua new guinea       97.5    2.609375    -9999.0   -9999.0   -9999.0
# south africa           97.5    7.453125    -9999.0   -9999.0   -9999.0
# usa                    97.5    5.203125    -9999.0   -9999.0   -9999.0
#
#                      temp2m  lifted_index       rh2m  msl_pressure  \
# pais
# australia         22.140625      2.500000  10.953125   1023.578125
# new zealand       10.640625     10.125000   9.328125   1026.687500
# papua new guinea  25.875000      1.859375  11.000000   1011.750000
# south africa      16.890625      3.453125  12.265625   1017.093750
# usa               24.671875     -0.125000   7.140625   1014.218750
#
#                   prec_amount  snow_depth  wind10m.speed    latitud  \
# pais
# australia            3.234375         0.0       3.328125 -24.776109
# new zealand          2.453125         0.0       3.437500 -41.500083
# papua new guinea     2.828125         0.0       3.718750  -5.681607
# south africa         5.453125         0.0       2.937500 -28.816624
# usa                  2.234375         0.0       2.171875  39.783730
#
#                     longitud  rh_layer_950mb  rh_layer_900mb  rh_layer_850mb  \
# pais
# australia         134.755000       13.921875       11.203125        8.187500
# new zealand       172.834408       11.562500       12.515625        6.375000
# papua new guinea  144.248908       13.390625       11.484375        8.437500
# south africa       24.991639       12.406250       11.843750       11.343750
# usa              -100.445882        9.765625       11.578125       11.296875
#
#                   rh_layer_800mb  rh_layer_750mb  rh_layer_700mb  \
# pais
# australia               5.906250        3.859375        1.828125
# new zealand             3.375000        1.328125        0.312500
# papua new guinea        5.625000        1.703125       -1.187500
# south africa           10.578125       10.640625        9.046875
# usa                    10.031250        7.968750        5.671875
#
#                   rh_layer_650mb  rh_layer_600mb  rh_layer_550mb  \
# pais
# australia              -0.968750       -1.984375       -2.171875
# new zealand             0.812500        0.109375        0.296875
# papua new guinea       -2.531250       -3.515625       -3.718750
# south africa            6.234375        4.000000        3.484375
# usa                     4.125000        3.765625        3.437500
#
#                   rh_layer_500mb  rh_layer_450mb  rh_layer_400mb  \
# pais
# australia              -1.796875       -0.734375       -0.281250
# new zealand             0.656250        1.437500        1.578125
# papua new guinea       -3.984375       -3.109375       -2.156250
# south africa            5.796875        6.984375        8.828125
# usa                     3.906250        4.484375        6.625000
#
#                   rh_layer_350mb  rh_layer_300mb  rh_layer_250mb  \
# pais
# australia               0.343750        2.468750        6.343750
# new zealand             3.031250        3.281250        4.062500
# papua new guinea       -1.765625       -1.687500       -1.390625
# south africa           10.843750        7.984375        7.031250
# usa                     8.296875        9.093750        9.281250
#
#                   rh_layer_200mb  layer950mb_direction  layer950mb_speed  \
# pais
# australia               3.671875             96.328125          3.546875
# new zealand             0.000000            272.109375          3.734375
# papua new guinea       -0.546875            105.781250          4.093750
# south africa            4.656250            189.609375          3.125000
# usa                     2.453125            171.640625          2.109375
#
#                   layer900mb_direction  layer900mb_speed  \
# pais
# australia                    91.953125          3.281250
# new zealand                 271.093750          3.703125
# papua new guinea            101.406250          4.234375
# south africa                200.859375          3.109375
# usa                         157.500000          2.234375
#
#                   layer850mb_direction  layer850mb_speed  \
# pais
# australia                    99.687500          2.953125
# new zealand                 270.156250          3.765625
# papua new guinea             98.437500          3.859375
# south africa                225.546875          3.109375
# usa                         172.890625          2.203125
#
#                   layer800mb_direction  layer800mb_speed  \
# pais
# australia                   112.187500          2.875000
# new zealand                 268.359375          3.828125
# papua new guinea             96.640625          3.109375
# south africa                249.140625          3.343750
# usa                         226.406250          2.421875
#
#                   layer750mb_direction  layer750mb_speed  \
# pais
# australia                   103.281250          2.796875
# new zealand                 266.640625          3.906250
# papua new guinea             84.218750          2.718750
# south africa                257.500000          3.421875
# usa                         238.828125          2.765625
#
#                   layer700mb_direction  layer700mb_speed  \
# pais
# australia                   105.859375          2.828125
# new zealand                 266.171875          3.937500
# papua new guinea             73.515625          2.453125
# south africa                268.984375          3.796875
# usa                         230.546875          2.953125
#
#                   layer650mb_direction  layer650mb_speed  \
# pais
# australia                   132.656250          2.750000
# new zealand                 265.703125          3.953125
# papua new guinea            123.437500          2.515625
# south africa                268.437500          4.328125
# usa                         208.046875          3.046875
#
#                   layer600mb_direction  layer600mb_speed  \
# pais
# australia                   189.140625          2.750000
# new zealand                 266.640625          4.000000
# papua new guinea            122.343750          2.718750
# south africa                269.218750          5.046875
# usa                         198.906250          3.093750
#
#                   layer550mb_direction  layer550mb_speed  \
# pais
# australia                   206.015625          3.218750
# new zealand                 266.562500          4.093750
# papua new guinea            108.359375          3.078125
# south africa                270.000000          5.734375
# usa                         205.156250          3.203125
#
#                   layer500mb_direction  layer500mb_speed  \
# pais
# australia                   227.812500          3.390625
# new zealand                 252.031250          4.343750
# papua new guinea            100.859375          3.218750
# south africa                275.312500          6.390625
# usa                         230.781250          3.281250
#
#                   layer450mb_direction  layer450mb_speed  \
# pais
# australia                   238.046875          4.000000
# new zealand                 254.375000          4.453125
# papua new guinea            126.171875          2.828125
# south africa                275.468750          6.718750
# usa                         253.359375          3.375000
#
#                   layer400mb_direction  layer400mb_speed  \
# pais
# australia                   254.062500          4.500000
# new zealand                 248.828125          4.656250
# papua new guinea            141.328125          3.203125
# south africa                270.937500          7.296875
# usa                         240.078125          3.703125
#
#                   layer350mb_direction  layer350mb_speed  \
# pais
# australia                   255.937500          4.765625
# new zealand                 238.671875          5.015625
# papua new guinea            210.937500          3.781250
# south africa                275.312500          8.437500
# usa                         236.718750          3.890625
#
#                   layer300mb_direction  layer300mb_speed  \
# pais
# australia                   253.750000          5.203125
# new zealand                 242.109375          5.203125
# papua new guinea            265.000000          4.765625
# south africa                272.031250          9.515625
# usa                         236.406250          4.500000
#
#                   layer250mb_direction  layer250mb_speed  \
# pais
# australia                   246.875000          5.750000
# new zealand                 256.953125          5.359375
# papua new guinea            278.750000          4.750000
# south africa                269.531250         10.468750
# usa                         250.859375          5.015625
#
#                   layer200mb_direction  layer200mb_speed
# pais
# australia                   252.343750          6.375000
# new zealand                 265.703125          5.703125
# papua new guinea            269.296875          4.875000
# south africa                267.109375         10.437500
# usa                         281.093750          5.359375

# %%
# Estamos listas para mergear con el df paises con la informacion de los ataques de tiburón

# %% [markdown]
# ##### Unimos los df clima3 y df paises

# %%
# Vemos el nombre de las columnas por las que vamos a mergear
df_paises.columns
# Out:
# Index(['year', 'type', 'country', 'age', 'species_', 'fecha_limpia', 'fatal',
#        'sex', 'latitud', 'longitud', 'country2', 'fatal_N', 'fatal_Unknown',
#        'fatal_Y', 'fatal_N.1', 'fatal_Unknown.1', 'fatal_Y.1', 'species_.1',
#        'fecha_limpia.1', 'type.1', 'age_NORM'],
#       dtype='object')

# %%
df_grupo_clima.columns
# Out:
# Index(['timepoint', 'cloudcover', 'highcloud', 'midcloud', 'lowcloud',
#        'temp2m', 'lifted_index', 'rh2m', 'msl_pressure', 'prec_amount',
#        'snow_depth', 'wind10m.speed', 'latitud', 'longitud', 'rh_layer_950mb',
#        'rh_layer_900mb', 'rh_layer_850mb', 'rh_layer_800mb', 'rh_layer_750mb',
#        'rh_layer_700mb', 'rh_layer_650mb', 'rh_layer_600mb', 'rh_layer_550mb',
#        'rh_layer_500mb', 'rh_layer_450mb', 'rh_layer_400mb', 'rh_layer_350mb',
#        'rh_layer_300mb', 'rh_layer_250mb', 'rh_layer_200mb',
#        'layer950mb_direction', 'layer950mb_speed', 'layer900mb_direction',
#        'layer900mb_speed', 'layer850mb_direction', 'layer850mb_speed',
#        'layer800mb_direction', 'layer800mb_speed', 'layer750mb_direction',
#        'layer750mb_speed', 'layer700mb_direction', 'layer700mb_speed',
#        'layer650mb_direction', 'layer650mb_speed', 'layer600mb_direction',
#        'layer600mb_speed', 'layer550mb_direction', 'layer550mb_speed',
#        'layer500mb_direction', 'layer500mb_speed', 'layer450mb_direction',
#        'layer450mb_speed', 'layer400mb_direction', 'layer400mb_speed',
#        'layer350mb_direction', 'layer350mb_speed', 'layer300mb_direction',
#        'layer300mb_speed', 'layer250mb_direction', 'layer250mb_speed',
#        'layer200mb_direction', 'layer200mb_speed'],
#       dtype='object')

# %%
df_attacks_clima_paises = df_paises.merge(df_grupo_clima, left_on=['country'] , right_on=['pais'])
df_attacks_clima_paises.head()
# Out:
#    year        type country   age     species_ fecha_limpia fatal sex  \
# 0  2018     Boating     usa  57.0  White shark          Jun     N   F
# 1  2018  Unprovoked     usa  11.0  Unespecific          Jun     N   F
# 2  2018     Invalid     usa  48.0  Unespecific          Jun     N   M
# 3  2018  Unprovoked     usa  52.0  Lemon shark          May     N   M
# 4  2018  Unprovoked     usa  15.0  Lemon shark          May     N   M
#
#    latitud_x  longitud_x country2  fatal_N  fatal_Unknown  fatal_Y  fatal_N.1  \
# 0   39.78373 -100.445882       HN        1              0        0          1
# 1   39.78373 -100.445882       HN        1              0        0          1
# 2   39.78373 -100.445882       HN        1              0        0          1
# 3   39.78373 -100.445882       HN        1              0        0          1
# 4   39.78373 -100.445882       HN        1              0        0          1
#
#    fatal_Unknown.1  fatal_Y.1  species_.1  fecha_limpia.1  type.1  age_NORM  \
# 0                0          0           4               7       1  9.116327
# 1                0          0           3               7       7  3.804860
# 2                0          0           3               7       3  8.403629
# 3                0          0           1               9       7  8.730109
# 4                0          0           1               9       7  4.581659
#
#    timepoint  cloudcover  highcloud  midcloud  lowcloud     temp2m  \
# 0       97.5    5.203125    -9999.0   -9999.0   -9999.0  24.671875
# 1       97.5    5.203125    -9999.0   -9999.0   -9999.0  24.671875
# 2       97.5    5.203125    -9999.0   -9999.0   -9999.0  24.671875
# 3       97.5    5.203125    -9999.0   -9999.0   -9999.0  24.671875
# 4       97.5    5.203125    -9999.0   -9999.0   -9999.0  24.671875
#
#    lifted_index      rh2m  msl_pressure  prec_amount  snow_depth  \
# 0        -0.125  7.140625    1014.21875     2.234375         0.0
# 1        -0.125  7.140625    1014.21875     2.234375         0.0
# 2        -0.125  7.140625    1014.21875     2.234375         0.0
# 3        -0.125  7.140625    1014.21875     2.234375         0.0
# 4        -0.125  7.140625    1014.21875     2.234375         0.0
#
#    wind10m.speed  latitud_y  longitud_y  rh_layer_950mb  rh_layer_900mb  \
# 0       2.171875   39.78373 -100.445882        9.765625       11.578125
# 1       2.171875   39.78373 -100.445882        9.765625       11.578125
# 2       2.171875   39.78373 -100.445882        9.765625       11.578125
# 3       2.171875   39.78373 -100.445882        9.765625       11.578125
# 4       2.171875   39.78373 -100.445882        9.765625       11.578125
#
#    rh_layer_850mb  rh_layer_800mb  rh_layer_750mb  rh_layer_700mb  \
# 0       11.296875        10.03125         7.96875        5.671875
# 1       11.296875        10.03125         7.96875        5.671875
# 2       11.296875        10.03125         7.96875        5.671875
# 3       11.296875        10.03125         7.96875        5.671875
# 4       11.296875        10.03125         7.96875        5.671875
#
#    rh_layer_650mb  rh_layer_600mb  rh_layer_550mb  rh_layer_500mb  \
# 0           4.125        3.765625          3.4375         3.90625
# 1           4.125        3.765625          3.4375         3.90625
# 2           4.125        3.765625          3.4375         3.90625
# 3           4.125        3.765625          3.4375         3.90625
# 4           4.125        3.765625          3.4375         3.90625
#
#    rh_layer_450mb  rh_layer_400mb  rh_layer_350mb  rh_layer_300mb  \
# 0        4.484375           6.625        8.296875         9.09375
# 1        4.484375           6.625        8.296875         9.09375
# 2        4.484375           6.625        8.296875         9.09375
# 3        4.484375           6.625        8.296875         9.09375
# 4        4.484375           6.625        8.296875         9.09375
#
#    rh_layer_250mb  rh_layer_200mb  layer950mb_direction  layer950mb_speed  \
# 0         9.28125        2.453125            171.640625          2.109375
# 1         9.28125        2.453125            171.640625          2.109375
# 2         9.28125        2.453125            171.640625          2.109375
# 3         9.28125        2.453125            171.640625          2.109375
# 4         9.28125        2.453125            171.640625          2.109375
#
#    layer900mb_direction  layer900mb_speed  layer850mb_direction  \
# 0                 157.5          2.234375            172.890625
# 1                 157.5          2.234375            172.890625
# 2                 157.5          2.234375            172.890625
# 3                 157.5          2.234375            172.890625
# 4                 157.5          2.234375            172.890625
#
#    layer850mb_speed  layer800mb_direction  layer800mb_speed  \
# 0          2.203125             226.40625          2.421875
# 1          2.203125             226.40625          2.421875
# 2          2.203125             226.40625          2.421875
# 3          2.203125             226.40625          2.421875
# 4          2.203125             226.40625          2.421875
#
#    layer750mb_direction  layer750mb_speed  layer700mb_direction  \
# 0            238.828125          2.765625            230.546875
# 1            238.828125          2.765625            230.546875
# 2            238.828125          2.765625            230.546875
# 3            238.828125          2.765625            230.546875
# 4            238.828125          2.765625            230.546875
#
#    layer700mb_speed  layer650mb_direction  layer650mb_speed  \
# 0          2.953125            208.046875          3.046875
# 1          2.953125            208.046875          3.046875
# 2          2.953125            208.046875          3.046875
# 3          2.953125            208.046875          3.046875
# 4          2.953125            208.046875          3.046875
#
#    layer600mb_direction  layer600mb_speed  layer550mb_direction  \
# 0             198.90625           3.09375             205.15625
# 1             198.90625           3.09375             205.15625
# 2             198.90625           3.09375             205.15625
# 3             198.90625           3.09375             205.15625
# 4             198.90625           3.09375             205.15625
#
#    layer550mb_speed  layer500mb_direction  layer500mb_speed  \
# 0          3.203125             230.78125           3.28125
# 1          3.203125             230.78125           3.28125
# 2          3.203125             230.78125           3.28125
# 3          3.203125             230.78125           3.28125
# 4          3.203125             230.78125           3.28125
#
#    layer450mb_direction  layer450mb_speed  layer400mb_direction  \
# 0            253.359375             3.375            240.078125
# 1            253.359375             3.375            240.078125
# 2            253.359375             3.375            240.078125
# 3            253.359375             3.375            240.078125
# 4            253.359375             3.375            240.078125
#
#    layer400mb_speed  layer350mb_direction  layer350mb_speed  \
# 0          3.703125             236.71875          3.890625
# 1          3.703125             236.71875          3.890625
# 2          3.703125             236.71875          3.890625
# 3          3.703125             236.71875          3.890625
# 4          3.703125             236.71875          3.890625
#
#    layer300mb_direction  layer300mb_speed  layer250mb_direction  \
# 0             236.40625               4.5            250.859375
# 1             236.40625               4.5            250.859375
# 2             236.40625               4.5            250.859375
# 3             236.40625               4.5            250.859375
# 4             236.40625               4.5            250.859375
#
#    layer250mb_speed  layer200mb_direction  layer200mb_speed
# 0          5.015625             281.09375          5.359375
# 1          5.015625             281.09375          5.359375
# 2          5.015625             281.09375          5.359375
# 3          5.015625             281.09375          5.359375
# 4          5.015625             281.09375          5.359375

# %%
# Comprobamos nulos
df_attacks_clima_paises.isnull().sum()
# Out:
# year                    0
# type                    0
# country                 0
# age                     0
# species_                0
# fecha_limpia            0
# fatal                   0
# sex                     0
# latitud_x               0
# longitud_x              0
# country2                0
# fatal_N                 0
# fatal_Unknown           0
# fatal_Y                 0
# fatal_N.1               0
# fatal_Unknown.1         0
# fatal_Y.1               0
# species_.1              0
# fecha_limpia.1          0
# type.1                  0
# age_NORM                0
# timepoint               0
# cloudcover              0
# highcloud               0
# midcloud                0
# lowcloud                0
# temp2m                  0
# lifted_index            0
# rh2m                    0
# msl_pressure            0
# prec_amount             0
# snow_depth              0
# wind10m.speed           0
# latitud_y               0
# longitud_y              0
# rh_layer_950mb          0
# rh_layer_900mb          0
# rh_layer_850mb          0
# rh_layer_800mb          0
# rh_layer_750mb          0
# rh_layer_700mb          0
# rh_layer_650mb          0
# rh_layer_600mb          0
# rh_layer_550mb          0
# rh_layer_500mb          0
# rh_layer_450mb          0
# rh_layer_400mb          0
# rh_layer_350mb          0
# rh_layer_300mb          0
# rh_layer_250mb          0
# rh_layer_200mb          0
# layer950mb_direction    0
# layer950mb_speed        0
# layer900mb_direction    0
# layer900mb_speed        0
# layer850mb_direction    0
# layer850mb_speed        0
# layer800mb_direction    0
# layer800mb_speed        0
# layer750mb_direction    0
# layer750mb_speed        0
# layer700mb_direction    0
# layer700mb_speed        0
# layer650mb_direction    0
# layer650mb_speed        0
# layer600mb_direction    0
# layer600mb_speed        0
# layer550mb_direction    0
# layer550mb_speed        0
# layer500mb_direction    0
# layer500mb_speed        0
# layer450mb_direction    0
# layer450mb_speed        0
# layer400mb_direction    0
# layer400mb_speed        0
# layer350mb_direction    0
# layer350mb_speed        0
# layer300mb_direction    0
# layer300mb_speed        0
# layer250mb_direction    0
# layer250mb_speed        0
# layer200mb_direction    0
# layer200mb_speed        0
# dtype: int64

# %%
df_attacks_clima_paises['rh_layer_950mb'].isnull().sum()
# Out:
# 0

# %%
df_attacks_clima_paises.shape
# Out:
# (4335, 83)

# %%
df_attacks_clima_paises['country'].unique()
# Out:
# array(['usa', 'australia', 'south africa', 'new zealand',
#        'papua new guinea'], dtype=object)

# %%
# Mergeo correcto

# %% [markdown]
# ##### Guardamos en csv y en pickle

# %%
df_attacks_clima_paises.to_csv('datos/output/attacks_clima_paises.csv')

# %%
df_attacks_clima_paises.to_pickle('datos/output/attacks_clima_paises.pkl')

# %% [markdown]
# ##### **Razonamiento detrás del for loop para la columna `wind_profile` (aplicado tambien para la columna rh_profile)

# %%
df_wind.head()
# Out:
#                                                  0   \
# 0  {'layer': '950mb', 'direction': 155, 'speed': 2}
# 1  {'layer': '950mb', 'direction': 155, 'speed': 2}
# 2  {'layer': '950mb', 'direction': 120, 'speed': 3}
# 3  {'layer': '950mb', 'direction': 110, 'speed': 2}
# 4  {'layer': '950mb', 'direction': 265, 'speed': 2}
#
#                                                  1   \
# 0  {'layer': '900mb', 'direction': 145, 'speed': 3}
# 1  {'layer': '900mb', 'direction': 185, 'speed': 2}
# 2  {'layer': '900mb', 'direction': 145, 'speed': 2}
# 3  {'layer': '900mb', 'direction': 105, 'speed': 2}
# 4   {'layer': '900mb', 'direction': 35, 'speed': 2}
#
#                                                  2   \
# 0  {'layer': '850mb', 'direction': 160, 'speed': 3}
# 1  {'layer': '850mb', 'direction': 230, 'speed': 2}
# 2  {'layer': '850mb', 'direction': 245, 'speed': 2}
# 3  {'layer': '850mb', 'direction': 160, 'speed': 2}
# 4   {'layer': '850mb', 'direction': 80, 'speed': 2}
#
#                                                  3   \
# 0  {'layer': '800mb', 'direction': 230, 'speed': 2}
# 1  {'layer': '800mb', 'direction': 235, 'speed': 3}
# 2  {'layer': '800mb', 'direction': 260, 'speed': 3}
# 3  {'layer': '800mb', 'direction': 230, 'speed': 2}
# 4  {'layer': '800mb', 'direction': 250, 'speed': 2}
#
#                                                  4   \
# 0  {'layer': '750mb', 'direction': 250, 'speed': 3}
# 1  {'layer': '750mb', 'direction': 250, 'speed': 3}
# 2  {'layer': '750mb', 'direction': 275, 'speed': 3}
# 3  {'layer': '750mb', 'direction': 255, 'speed': 3}
# 4  {'layer': '750mb', 'direction': 270, 'speed': 2}
#
#                                                  5   \
# 0  {'layer': '700mb', 'direction': 260, 'speed': 3}
# 1  {'layer': '700mb', 'direction': 255, 'speed': 3}
# 2  {'layer': '700mb', 'direction': 270, 'speed': 3}
# 3  {'layer': '700mb', 'direction': 275, 'speed': 4}
# 4  {'layer': '700mb', 'direction': 270, 'speed': 3}
#
#                                                  6   \
# 0  {'layer': '650mb', 'direction': 250, 'speed': 4}
# 1  {'layer': '650mb', 'direction': 240, 'speed': 3}
# 2  {'layer': '650mb', 'direction': 245, 'speed': 3}
# 3  {'layer': '650mb', 'direction': 280, 'speed': 3}
# 4  {'layer': '650mb', 'direction': 270, 'speed': 3}
#
#                                                  7   \
# 0  {'layer': '600mb', 'direction': 240, 'speed': 4}
# 1  {'layer': '600mb', 'direction': 230, 'speed': 4}
# 2  {'layer': '600mb', 'direction': 240, 'speed': 4}
# 3  {'layer': '600mb', 'direction': 245, 'speed': 3}
# 4  {'layer': '600mb', 'direction': 250, 'speed': 3}
#
#                                                  8   \
# 0  {'layer': '550mb', 'direction': 235, 'speed': 5}
# 1  {'layer': '550mb', 'direction': 235, 'speed': 5}
# 2  {'layer': '550mb', 'direction': 245, 'speed': 4}
# 3  {'layer': '550mb', 'direction': 250, 'speed': 4}
# 4  {'layer': '550mb', 'direction': 245, 'speed': 3}
#
#                                                  9   \
# 0  {'layer': '500mb', 'direction': 235, 'speed': 5}
# 1  {'layer': '500mb', 'direction': 235, 'speed': 5}
# 2  {'layer': '500mb', 'direction': 250, 'speed': 5}
# 3  {'layer': '500mb', 'direction': 245, 'speed': 4}
# 4  {'layer': '500mb', 'direction': 240, 'speed': 3}
#
#                                                  10  \
# 0  {'layer': '450mb', 'direction': 235, 'speed': 5}
# 1  {'layer': '450mb', 'direction': 240, 'speed': 5}
# 2  {'layer': '450mb', 'direction': 245, 'speed': 5}
# 3  {'layer': '450mb', 'direction': 240, 'speed': 4}
# 4  {'layer': '450mb', 'direction': 245, 'speed': 3}
#
#                                                  11  \
# 0  {'layer': '400mb', 'direction': 235, 'speed': 5}
# 1  {'layer': '400mb', 'direction': 245, 'speed': 5}
# 2  {'layer': '400mb', 'direction': 245, 'speed': 5}
# 3  {'layer': '400mb', 'direction': 245, 'speed': 4}
# 4  {'layer': '400mb', 'direction': 245, 'speed': 4}
#
#                                                  12  \
# 0  {'layer': '350mb', 'direction': 230, 'speed': 5}
# 1  {'layer': '350mb', 'direction': 250, 'speed': 5}
# 2  {'layer': '350mb', 'direction': 255, 'speed': 5}
# 3  {'layer': '350mb', 'direction': 245, 'speed': 5}
# 4  {'layer': '350mb', 'direction': 245, 'speed': 4}
#
#                                                  13  \
# 0  {'layer': '300mb', 'direction': 235, 'speed': 6}
# 1  {'layer': '300mb', 'direction': 250, 'speed': 6}
# 2  {'layer': '300mb', 'direction': 250, 'speed': 5}
# 3  {'layer': '300mb', 'direction': 245, 'speed': 5}
# 4  {'layer': '300mb', 'direction': 250, 'speed': 5}
#
#                                                  14  \
# 0  {'layer': '250mb', 'direction': 230, 'speed': 7}
# 1  {'layer': '250mb', 'direction': 240, 'speed': 6}
# 2  {'layer': '250mb', 'direction': 245, 'speed': 5}
# 3  {'layer': '250mb', 'direction': 255, 'speed': 5}
# 4  {'layer': '250mb', 'direction': 245, 'speed': 5}
#
#                                                  15
# 0  {'layer': '200mb', 'direction': 235, 'speed': 7}
# 1  {'layer': '200mb', 'direction': 250, 'speed': 6}
# 2  {'layer': '200mb', 'direction': 255, 'speed': 6}
# 3  {'layer': '200mb', 'direction': 255, 'speed': 6}
# 4  {'layer': '200mb', 'direction': 255, 'speed': 5}

# %%
# Desempaquetamos una columna
des_dicc = df_wind[0].apply(pd.Series)
des_dicc
# Out:
#      layer  direction  speed
# 0    950mb        155      2
# 1    950mb        155      2
# 2    950mb        120      3
# 3    950mb        110      2
# 4    950mb        265      2
# 5    950mb        320      2
# 6    950mb        335      2
# 7    950mb        355      2
# 8    950mb         10      2
# 9    950mb        110      2
# 10   950mb        170      2
# 11   950mb        205      2
# 12   950mb        200      2
# 13   950mb        230      2
# 14   950mb        240      2
# 15   950mb        300      2
# 16   950mb        250      2
# 17   950mb        165      3
# 18   950mb        105      3
# 19   950mb        140      2
# 20   950mb        155      2
# 21   950mb        105      2
# 22   950mb        105      2
# 23   950mb        160      2
# 24   950mb        165      2
# 25   950mb        185      2
# 26   950mb        200      2
# 27   950mb        185      2
# 28   950mb        200      2
# 29   950mb        190      2
# 30   950mb        205      2
# 31   950mb        295      2
# 32   950mb        110      2
# 33   950mb        130      2
# 34   950mb        155      3
# 35   950mb        170      2
# 36   950mb        175      2
# 37   950mb        190      2
# 38   950mb        160      2
# 39   950mb        100      2
# 40   950mb        155      2
# 41   950mb        165      3
# 42   950mb        155      3
# 43   950mb        180      2
# 44   950mb        195      3
# 45   950mb        200      2
# 46   950mb        190      2
# 47   950mb        210      2
# 48   950mb        190      2
# 49   950mb        175      2
# 50   950mb        165      3
# 51   950mb        155      3
# 52   950mb        205      2
# 53   950mb        190      2
# 54   950mb         10      1
# 55   950mb         65      2
# 56   950mb         95      2
# 57   950mb        120      2
# 58   950mb        115      2
# 59   950mb        110      2
# 60   950mb        125      2
# 61   950mb        130      2
# 62   950mb        135      2
# 63   950mb        270      1
# 64   950mb        165      4
# 65   950mb        170      5
# 66   950mb        165      5
# 67   950mb        155      5
# 68   950mb        150      5
# 69   950mb        155      5
# 70   950mb        145      5
# 71   950mb        150      5
# 72   950mb        145      4
# 73   950mb        145      4
# 74   950mb        140      4
# 75   950mb        140      4
# 76   950mb        135      4
# 77   950mb        120      4
# 78   950mb        110      4
# 79   950mb         95      4
# 80   950mb         90      3
# 81   950mb        100      3
# 82   950mb        105      3
# 83   950mb        105      4
# 84   950mb        105      4
# 85   950mb        100      4
# 86   950mb        105      4
# 87   950mb         95      4
# 88   950mb         85      3
# 89   950mb         85      3
# 90   950mb         85      3
# 91   950mb         85      3
# 92   950mb         70      3
# 93   950mb         65      3
# 94   950mb         60      3
# 95   950mb         50      3
# 96   950mb         40      3
# 97   950mb         40      3
# 98   950mb         40      3
# 99   950mb         55      3
# 100  950mb         65      3
# 101  950mb         65      2
# 102  950mb         65      3
# 103  950mb         50      3
# 104  950mb         55      3
# 105  950mb         60      3
# 106  950mb         75      3
# 107  950mb         85      3
# 108  950mb         80      3
# 109  950mb        100      3
# 110  950mb        110      3
# 111  950mb        105      3
# 112  950mb         90      3
# 113  950mb         90      3
# 114  950mb         90      4
# 115  950mb         90      4
# 116  950mb         85      4
# 117  950mb         90      4
# 118  950mb         95      4
# 119  950mb         95      4
# 120  950mb         95      4
# 121  950mb         95      3
# 122  950mb         95      3
# 123  950mb         85      4
# 124  950mb         75      3
# 125  950mb         80      3
# 126  950mb         75      3
# 127  950mb         75      3
# 128  950mb         35      4
# 129  950mb         20      5
# 130  950mb          0      5
# 131  950mb        320      5
# 132  950mb        310      5
# 133  950mb        305      5
# 134  950mb        295      5
# 135  950mb        260      4
# 136  950mb        260      3
# 137  950mb        270      3
# 138  950mb        270      3
# 139  950mb        260      3
# 140  950mb        285      3
# 141  950mb        290      3
# 142  950mb        305      3
# 143  950mb        305      3
# 144  950mb        300      3
# 145  950mb        320      3
# 146  950mb        325      3
# 147  950mb        300      3
# 148  950mb        325      3
# 149  950mb        350      3
# 150  950mb         25      3
# 151  950mb        355      3
# 152  950mb         10      4
# 153  950mb        350      4
# 154  950mb        340      4
# 155  950mb        345      3
# 156  950mb         35      3
# 157  950mb         30      3
# 158  950mb        320      3
# 159  950mb        325      3
# 160  950mb        285      3
# 161  950mb        235      2
# 162  950mb        210      2
# 163  950mb        175      2
# 164  950mb        200      3
# 165  950mb        200      3
# 166  950mb        205      3
# 167  950mb        165      3
# 168  950mb        120      3
# 169  950mb        115      3
# 170  950mb        115      3
# 171  950mb        105      3
# 172  950mb         85      3
# 173  950mb         90      3
# 174  950mb         80      3
# 175  950mb         70      3
# 176  950mb         75      3
# 177  950mb         75      4
# 178  950mb         10      3
# 179  950mb        355      3
# 180  950mb        350      2
# 181  950mb          5      2
# 182  950mb        320      2
# 183  950mb        325      2
# 184  950mb         50      2
# 185  950mb         30      2
# 186  950mb         20      2
# 187  950mb         60      2
# 188  950mb         55      3
# 189  950mb         45      3
# 190  950mb         30      3
# 191  950mb         30      4
# 192  950mb        300      3
# 193  950mb        330      3
# 194  950mb        300      3
# 195  950mb        270      3
# 196  950mb        275      4
# 197  950mb        255      5
# 198  950mb        240      5
# 199  950mb        215      5
# 200  950mb        210      5
# 201  950mb        205      4
# 202  950mb        205      3
# 203  950mb        210      3
# 204  950mb        240      3
# 205  950mb        245      3
# 206  950mb        250      3
# 207  950mb        240      3
# 208  950mb        240      3
# 209  950mb        240      4
# 210  950mb        230      4
# 211  950mb        225      4
# 212  950mb        220      4
# 213  950mb        225      4
# 214  950mb        215      4
# 215  950mb        210      4
# 216  950mb        215      3
# 217  950mb        215      3
# 218  950mb        215      3
# 219  950mb        210      3
# 220  950mb        205      2
# 221  950mb        245      2
# 222  950mb        270      2
# 223  950mb        320      2
# 224  950mb        330      3
# 225  950mb        335      3
# 226  950mb        335      3
# 227  950mb        330      3
# 228  950mb        335      3
# 229  950mb        330      4
# 230  950mb        325      4
# 231  950mb        330      4
# 232  950mb        325      4
# 233  950mb        330      4
# 234  950mb        335      4
# 235  950mb        335      4
# 236  950mb        335      5
# 237  950mb        340      5
# 238  950mb        340      5
# 239  950mb        340      5
# 240  950mb        335      5
# 241  950mb        340      5
# 242  950mb        335      5
# 243  950mb        330      5
# 244  950mb        325      5
# 245  950mb        320      6
# 246  950mb        310      5
# 247  950mb        295      5
# 248  950mb        295      4
# 249  950mb        285      4
# 250  950mb        275      3
# 251  950mb        225      3
# 252  950mb        205      3
# 253  950mb        195      3
# 254  950mb        175      3
# 255  950mb        150      3
# 256  950mb        105      4
# 257  950mb        105      4
# 258  950mb        115      4
# 259  950mb        105      5
# 260  950mb        115      4
# 261  950mb        115      4
# 262  950mb        115      4
# 263  950mb        115      4
# 264  950mb        110      4
# 265  950mb        110      4
# 266  950mb        110      4
# 267  950mb        110      4
# 268  950mb        115      4
# 269  950mb        120      4
# 270  950mb        120      4
# 271  950mb        130      4
# 272  950mb        125      4
# 273  950mb        125      4
# 274  950mb        125      4
# 275  950mb        125      4
# 276  950mb        120      4
# 277  950mb        120      4
# 278  950mb        120      4
# 279  950mb        115      4
# 280  950mb        115      4
# 281  950mb        115      4
# 282  950mb        115      4
# 283  950mb        110      4
# 284  950mb        110      4
# 285  950mb        110      4
# 286  950mb        110      4
# 287  950mb        105      4
# 288  950mb        100      4
# 289  950mb        100      4
# 290  950mb         95      4
# 291  950mb         95      4
# 292  950mb         95      4
# 293  950mb         95      4
# 294  950mb         95      4
# 295  950mb        100      4
# 296  950mb        100      4
# 297  950mb        100      4
# 298  950mb        100      4
# 299  950mb        100      4
# 300  950mb         95      4
# 301  950mb         90      4
# 302  950mb         95      4
# 303  950mb         95      5
# 304  950mb         95      4
# 305  950mb         95      5
# 306  950mb         90      5
# 307  950mb         95      5
# 308  950mb         95      5
# 309  950mb         95      4
# 310  950mb        100      4
# 311  950mb         95      4
# 312  950mb        100      4
# 313  950mb        100      4
# 314  950mb        100      4
# 315  950mb        100      4
# 316  950mb         95      4
# 317  950mb         90      4
# 318  950mb         95      4
# 319  950mb        100      4

# %%
# Sacamos uno de los diccionarios
des_dicc.iloc[0,:]
# Out:
# layer        950mb
# direction      155
# speed            2
# Name: 0, dtype: object

# %%
# Construimos el nombre de la columna
layer = des_dicc.iloc[0,:].index[0]
layer
# Out:
# 'layer'

# %%
num = des_dicc.iloc[0,:].values[0]
num
# Out:
# '950mb'

# %%
direction = des_dicc.iloc[0,:].index[1]
direction
# Out:
# 'direction'

# %%
speed = des_dicc.iloc[0,:].index[2]
speed
# Out:
# 'speed'

# %%
# Sacamos los valores de cada fila
value_dir = des_dicc.iloc[0,:].values[1]
value_dir
# Out:
# 155

# %%
value_sp= des_dicc.iloc[0,:].values[2]
value_sp
# Out:
# 2

# %%
# Copiaremos todas estas variables para nuestro for loop para iterar por cada columna y dentro de cada columna extraer los valores de todas las filas
layer = des_dicc.iloc[0,:].index[0]
num = des_dicc.iloc[0,:].values[0]
direction = des_dicc.iloc[0,:].index[1]
speed = des_dicc.iloc[0,:].index[2]
value_dir = des_dicc.iloc[0,:].values[1]
value_sp= des_dicc.iloc[0,:].values[2]
